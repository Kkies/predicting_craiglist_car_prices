# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import random
import seaborn as sns
import math
import re
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 500)

# %% [markdown]
# ### Read data in

# %%
df = pd.read_csv('vehicles.csv')

# %% [markdown]
# ### Initial EDA

# %%
df.columns
# Out:
# Index(['id', 'url', 'region', 'region_url', 'price', 'year', 'manufacturer',
#        'model', 'condition', 'cylinders', 'fuel', 'odometer', 'title_status',
#        'transmission', 'vin', 'drive', 'size', 'type', 'paint_color',
#        'image_url', 'description', 'county', 'state', 'lat', 'long'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# id                   0
# url                  0
# region               0
# region_url           0
# price                0
# year              1117
# manufacturer     20747
# model             6199
# condition       186806
# cylinders       166384
# fuel              2991
# odometer         75148
# title_status      1806
# transmission      2146
# vin             196652
# drive           122011
# size            295961
# type            117108
# paint_color     135247
# image_url           24
# description         27
# county          435849
# state                0
# lat               8235
# long              8235
# dtype: int64

# %%
100 * df.isnull().sum() / len(df)
# Out:
# id                0.000000
# url               0.000000
# region            0.000000
# region_url        0.000000
# price             0.000000
# year              0.256281
# manufacturer      4.760135
# model             1.422282
# condition        42.860257
# cylinders        38.174689
# fuel              0.686247
# odometer         17.241751
# title_status      0.414364
# transmission      0.492372
# vin              45.119296
# drive            27.993869
# size             67.904481
# type             26.868939
# paint_color      31.030701
# image_url         0.005506
# description       0.006195
# county          100.000000
# state             0.000000
# lat               1.889416
# long              1.889416
# dtype: float64

# %%
plt.figure(figsize = (10,10))
sns.heatmap(df.isnull(), cbar=False);

# %%
df['manufacturer'].unique()
# Out:
# array(['jeep', 'bmw', 'dodge', 'chevrolet', nan, 'ford', 'ram', 'honda',
#        'toyota', 'nissan', 'subaru', 'gmc', 'volkswagen', 'kia', 'acura',
#        'chrysler', 'hyundai', 'cadillac', 'volvo', 'mini',
#        'mercedes-benz', 'audi', 'mazda', 'pontiac', 'buick', 'infiniti',
#        'mitsubishi', 'rover', 'lincoln', 'lexus', 'fiat', 'jaguar',
#        'mercury', 'saturn', 'datsun', 'porche', 'tesla',
#        'harley-davidson', 'ferrari', 'land rover', 'alfa-romeo', 'morgan',
#        'aston-martin'], dtype=object)

# %%
df.year.describe()
# Out:
# count    434732.000000
# mean       2009.866460
# std           9.312503
# min        1900.000000
# 25%        2007.000000
# 50%        2012.000000
# 75%        2015.000000
# max        2021.000000
# Name: year, dtype: float64

# %%
df.odometer.describe()
# Out:
# count    3.607010e+05
# mean     9.897590e+04
# std      1.134990e+05
# min      0.000000e+00
# 25%      4.733300e+04
# 50%      9.118800e+04
# 75%      1.347360e+05
# max      1.000000e+07
# Name: odometer, dtype: float64

# %%
df_clean = df.copy() #make copy of dataframe to use for our cleaned data

# %% [markdown]
# ### Imputing Manufacturer from Description

# %%
for i in list(df_clean['manufacturer'].unique()):
#     print (f'(df_clean["description"].str.contains("{i}", case = False)) & (df_clean["manufacturer"].isnull()),')
    print(f'"{i}",')
# Out:
# "jeep",
# "bmw",
# "dodge",
# "chevrolet",
# "nan",
# "ford",
# "ram",
# "honda",
# "toyota",
# "nissan",
# "subaru",
# "gmc",
# "volkswagen",
# "kia",
# "acura",
# "chrysler",
# "hyundai",
# "cadillac",
# "volvo",
# "mini",
# "mercedes-benz",
# "audi",
# "mazda",
# "pontiac",
# "buick",
# "infiniti",
# "mitsubishi",
# "rover",
# "lincoln",
# "lexus",
# "fiat",
# "jaguar",
# "mercury",
# "saturn",
# "datsun",
# "porche",
# "tesla",
# "harley-davidson",
# "ferrari",
# "land rover",
# "alfa-romeo",
# "morgan",
# "aston-martin",

# %%
condition = [
(df_clean["description"].str.contains("jeep", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("bmw", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("dodge", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("chevrolet", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("ford", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("honda", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("toyota", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("nissan", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("subaru", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("gmc", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("volkswagen", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("kia", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("acura", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("ram", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("chrysler", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("hyundai", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("cadillac", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("volvo", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("mini", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("mercedes-benz", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("nan", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("audi", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("mazda", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("pontiac", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("buick", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("infiniti", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("mitsubishi", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("rover", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("lincoln", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("lexus", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("fiat", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("jaguar", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("mercury", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("saturn", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("datsun", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("porche", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("tesla", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("harley-davidson", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("land rover", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("alfa-romeo", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("ferrari", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("morgan", case = False)) & (df_clean["manufacturer"].isnull()),
(df_clean["description"].str.contains("aston-martin", case = False)) & (df_clean["manufacturer"].isnull())
    
]
choice = [
            "jeep",
            "bmw",
            "dodge",
            "chevrolet",
            "ford",
            "honda",
            "toyota",
            "nissan",
            "subaru",
            "gmc",
            "volkswagen",
            "kia",
            "acura",
            "ram",
            "chrysler",
            "hyundai",
            "cadillac",
            "volvo",
            "mini",
            "mercedes-benz",
            "nan",
            "audi",
            "mazda",
            "pontiac",
            "buick",
            "infiniti",
            "mitsubishi",
            "rover",
            "lincoln",
            "lexus",
            "fiat",
            "jaguar",
            "mercury",
            "saturn",
            "datsun",
            "porche",
            "tesla",
            "harley-davidson",
            "land rover",
            "alfa-romeo",
            "ferrari",
            "morgan",
            "aston-martin"
]
df_clean['manufacturer'] = np.select(condition, choice, default = df_clean['manufacturer'])

# %%
df_clean.isnull().sum()
# Out:
# id                   0
# url                  0
# region               0
# region_url           0
# price                0
# year              1117
# manufacturer      8372
# model             6199
# condition       186806
# cylinders       166384
# fuel              2991
# odometer         75148
# title_status      1806
# transmission      2146
# vin             196652
# drive           122011
# size            295961
# type            117108
# paint_color     135247
# image_url           24
# description         27
# county          435849
# state                0
# lat               8235
# long              8235
# dtype: int64

# %% [markdown]
# ### Imputing Odometer Values (Thanks Alec)

# %%
df[df['odometer'] > 300000]
# Out:
#                 id                                                url  \
# 267     7120302677  https://oregoncoast.craigslist.org/ctd/d/portl...
# 932     7121507543  https://phoenix.craigslist.org/evl/cto/d/mesa-...
# 1002    7111631846  https://rapidcity.craigslist.org/ctd/d/windom-...
# 1053    7111563446  https://rapidcity.craigslist.org/ctd/d/windom-...
# 1157    7121484986  https://phoenix.craigslist.org/nph/cto/d/phoen...
# ...            ...                                                ...
# 434587  7109287314  https://richmond.craigslist.org/ctd/d/greensbo...
# 434815  7121452118  https://flagstaff.craigslist.org/cto/d/flagsta...
# 435297  7117495221  https://medford.craigslist.org/ctd/d/gladstone...
# 435728  7119682628  https://mohave.craigslist.org/cto/d/lake-havas...
# 435738  7121397652  https://oregoncoast.craigslist.org/ctd/d/portl...
#
#                       region                          region_url  price  \
# 267             oregon coast  https://oregoncoast.craigslist.org      0
# 932                  phoenix      https://phoenix.craigslist.org   1500
# 1002    rapid city / west SD    https://rapidcity.craigslist.org  14950
# 1053    rapid city / west SD    https://rapidcity.craigslist.org   9950
# 1157                 phoenix      https://phoenix.craigslist.org   9500
# ...                      ...                                 ...    ...
# 434587              richmond     https://richmond.craigslist.org      0
# 434815    flagstaff / sedona    https://flagstaff.craigslist.org   3100
# 435297       medford-ashland      https://medford.craigslist.org      0
# 435728         mohave county       https://mohave.craigslist.org   5900
# 435738          oregon coast  https://oregoncoast.craigslist.org      0
#
#           year manufacturer                  model  condition    cylinders  \
# 267     1996.0         ford                  f-250        NaN  8 cylinders
# 932     2007.0         ford                  focus       good  4 cylinders
# 1002    2015.0          NaN              ISUZU NRR  excellent  4 cylinders
# 1053    2005.0         ford              excursion       good  8 cylinders
# 1157    1994.0          NaN    freightliner fld120       good  6 cylinders
# ...        ...          ...                    ...        ...          ...
# 434587  2013.0          NaN          PETERBILT 389        NaN          NaN
# 434815  2007.0       toyota           prius hybrid       good  4 cylinders
# 435297  1999.0          ram  2500 laramie slt long  excellent  6 cylinders
# 435728  1999.0          gmc                  t6500        NaN          NaN
# 435738  1996.0         ford      f-250 xlt 2dr xlt        NaN  8 cylinders
#
#           fuel  odometer title_status transmission                vin drive  \
# 267     diesel  340272.0        clean       manual  1FTHX26F4TEA74745   4wd
# 932        gas  330000.0        clean    automatic                NaN   fwd
# 1002    diesel  300990.0        clean    automatic  JALE5W160F7302514   NaN
# 1053    diesel  302724.0        clean    automatic  1FMSU45P45EB76677   4wd
# 1157    diesel  400000.0        clean       manual                NaN   NaN
# ...        ...       ...          ...          ...                ...   ...
# 434587  diesel  714915.0        clean       manual  1XPXD49X7DD197000   NaN
# 434815  hybrid  308000.0        clean    automatic                NaN   fwd
# 435297  diesel  352781.0        clean    automatic  1B7KF2366XJ569670   4wd
# 435728  diesel  320000.0        clean       manual                NaN   NaN
# 435738  diesel  340272.0        clean       manual  1FTHX26F4TEA74745   4wd
#
#              size       type paint_color  \
# 267           NaN      truck         NaN
# 932       compact      sedan       black
# 1002    full-size      truck       white
# 1053    full-size        SUV        blue
# 1157          NaN        NaN         NaN
# ...           ...        ...         ...
# 434587        NaN        NaN         NaN
# 434815    compact  hatchback         red
# 435297  full-size      truck        blue
# 435728        NaN        NaN         NaN
# 435738        NaN      truck         NaN
#
#                                                 image_url  \
# 267     https://images.craigslist.org/00K0K_3wneG97zmf...
# 932     https://images.craigslist.org/00n0n_h6JcY0dnjE...
# 1002    https://images.craigslist.org/00101_a5nwKAiTlM...
# 1053    https://images.craigslist.org/01010_gBwSj7m7ll...
# 1157    https://images.craigslist.org/01313_87b6MXOX7S...
# ...                                                   ...
# 434587  https://images.craigslist.org/00x0x_f9Jlh6mMKV...
# 434815  https://images.craigslist.org/00Y0Y_dgt8zIdQQH...
# 435297  https://images.craigslist.org/00Y0Y_4t9sTDdkC5...
# 435728  https://images.craigslist.org/00n0n_5EsIro50yr...
# 435738  https://images.craigslist.org/00K0K_3wneG97zmf...
#
#                                               description  county state  \
# 267     Sunrise Auto SalesTry our Delivery Service , N...     NaN    or
# 932     Body excellent, interior excellent. Electric s...     NaN    az
# 1002    LA MOTORSPORTS DIESELTRUCKSMN.COM  2015 ISUZU ...     NaN    sd
# 1053    LA MOTORSPORTS DIESELTRUCKSMN.COM  2005 FORD E...     NaN    sd
# 1157    1994 freightliner FlD120 New steer Tirs  10 sp...     NaN    az
# ...                                                   ...     ...   ...
# 434587  Piedmont Peterbilt Internet Sales at 336-203-8...     NaN    va
# 434815  Everything works as it should A/c = COLD Heate...     NaN    az
# 435297  Carz Planet          STOCK #:  6498    💲 💲 FOR...     NaN    or
# 435728  GMC T6500 Stake Bed. 320k miles. CAT Diesel. E...     NaN    az
# 435738  Sunrise Auto SalesTry our Delivery Service , N...     NaN    or
#
#             lat      long
# 267     45.4072 -122.6250
# 932     33.3848 -111.8970
# 1002    43.8634  -95.1139
# 1053    43.8633  -95.1138
# 1157    33.6299 -112.1320
# ...         ...       ...
# 434587  36.0334  -79.8626
# 434815  35.1859 -111.6620
# 435297  45.3860 -122.6080
# 435728  34.4814 -114.3480
# 435738  45.4072 -122.6250
#
# [2427 rows x 25 columns]

# %%
plt.figure(figsize = (20,10))
df[(df['odometer'] < 300000) & (df['odometer'] > 250)]['odometer'].hist(bins = 200)
plt.axvline(df['odometer'].mean(), color = 'black')
plt.axvline(df[df['odometer'] < 1000000]['odometer'].mean(), color = 'orange')
plt.axvline(df[df['odometer'] < 300000]['odometer'].mean(), color = 'red')
plt.axvline(df[df['odometer'] < 200000]['odometer'].mean(), color = 'yellow')
plt.axvline(df[(df['odometer'] < 1000000) & (df['odometer'] > 1000)]['odometer'].mean(), color = 'orange', ls = ':')
plt.axvline(df[(df['odometer'] < 300000) & (df['odometer'] > 1000)]['odometer'].mean(), color = 'red', ls = ':')
plt.axvline(df[(df['odometer'] < 200000) & (df['odometer'] > 1000)]['odometer'].mean(), color = 'yellow', ls = ':')

# %%
bins = np.arange(df['year'].min(), df['year'].max(), 10)
bins = np.append(bins, 2021)
groups = pd.cut(df[(df['odometer'] < 300000) & (df['odometer'] > 250)]['year'], bins, include_lowest=True)

# %%
od_avgs = []
for i in range(1000):
    od_avgs.append(sum(random.sample(list(df[(df['odometer'] < 300000) & (df['odometer'] > 250)]['odometer']), 1000)) / 1000)
od_avg = sum(od_avgs) / 1000
od_avg
# Out:
# 96847.15636400011

# %%
((df_clean['description'].str.contains('ford', case = False)) & (df_clean['manufacturer'].isnull())).sum()
# Out:
# 0

# %%
df_clean['age'] = 2022-df_clean['year']

# %%
df_clean['miles_per_year'] = df_clean['odometer'] / df_clean['age']

# %%
estimated_annual_mileage = dict(df_clean.groupby(['manufacturer'])['miles_per_year'].median())
estimated_annual_mileage
# Out:
# {'acura': 9127.358299595142,
#  'alfa-romeo': 3649.0,
#  'aston-martin': 1642.857142857143,
#  'audi': 8328.125,
#  'bmw': 7699.78947368421,
#  'buick': 7519.818181818182,
#  'cadillac': 8316.5,
#  'chevrolet': 9250.0,
#  'chrysler': 9367.083333333334,
#  'datsun': 1752.375,
#  'dodge': 9461.625,
#  'ferrari': 1753.0202020202019,
#  'fiat': 5902.777777777777,
#  'ford': 9618.333333333334,
#  'gmc': 9873.78947368421,
#  'harley-davidson': 3166.6666666666665,
#  'honda': 9331.5,
#  'hyundai': 9196.833333333334,
#  'infiniti': 8643.066666666668,
#  'jaguar': 5545.454545454545,
#  'jeep': 8437.5,
#  'kia': 9335.222222222223,
#  'land rover': 7631.3,
#  'lexus': 8562.470588235294,
#  'lincoln': 8270.375,
#  'mazda': 8110.142857142857,
#  'mercedes-benz': 7467.666666666667,
#  'mercury': 7755.555555555556,
#  'mini': 7027.8125,
#  'mitsubishi': 7947.222222222223,
#  'morgan': 18997.4,
#  'nan': 7428.571428571428,
#  'nissan': 9209.166666666666,
#  'pontiac': 7543.738095238095,
#  'porche': 2352.9411764705883,
#  'ram': 9754.222222222223,
#  'rover': 8578.695804195804,
#  'saturn': 8301.07142857143,
#  'subaru': 9422.642857142857,
#  'tesla': 5935.0,
#  'toyota': 9419.866666666667,
#  'volkswagen': 8075.0,
#  'volvo': 9219.42857142857}

# %%
df_clean['estimated_odometer'] = df_clean['manufacturer'].map(estimated_annual_mileage) * df_clean['age']

# %%
conditions = [~df_clean['odometer'].isna(),
             df_clean['odometer'].isna()]

choices = [df_clean['odometer'],
          df_clean['estimated_odometer']]

df_clean['odometer'] = np.select(conditions, choices, default = np.nan)

df_clean.drop(['estimated_odometer'],axis=1,inplace=True)

df_clean.drop(['miles_per_year'],axis=1,inplace=True)

# %%
df_clean.isnull().sum()
# Out:
# id                   0
# url                  0
# region               0
# region_url           0
# price                0
# year              1117
# manufacturer      8372
# model             6199
# condition       186806
# cylinders       166384
# fuel              2991
# odometer          3893
# title_status      1806
# transmission      2146
# vin             196652
# drive           122011
# size            295961
# type            117108
# paint_color     135247
# image_url           24
# description         27
# county          435849
# state                0
# lat               8235
# long              8235
# age               1117
# dtype: int64

# %%
od_decade_means = df[(df['odometer'] < 300000) & (df['odometer'] > 250)].groupby(groups)['odometer'].agg(['mean', 'size']).head(500)

# %%
od_decade_means
# Out:
#                              mean    size
# year
# (1899.999, 1910.0]   86779.000000       1
# (1910.0, 1920.0]      7675.000000       6
# (1920.0, 1930.0]     34051.344828      58
# (1930.0, 1940.0]     24165.683761     117
# (1940.0, 1950.0]     41519.645833     144
# (1950.0, 1960.0]     49592.645892     353
# (1960.0, 1970.0]     59458.211575    1054
# (1970.0, 1980.0]     70270.250165    1511
# (1980.0, 1990.0]    105626.272727    2442
# (1990.0, 2000.0]    147959.196004   12612
# (2000.0, 2010.0]    138706.666248  109809
# (2010.0, 2020.0]     73904.297618  221455
# (2020.0, 2021.0]     88780.727273      11

# %%
conditions = [
                (df['year'] <= 1910) & (df['odometer'].isnull()),
                (df['year'] > 1910) & (df['year'] <= 1920) & (df['odometer'].isnull()),
                (df['year'] > 1920) & (df['year'] <= 1930) & (df['odometer'].isnull()),
                (df['year'] > 1930) & (df['year'] <= 1940) & (df['odometer'].isnull()),
                (df['year'] > 1940) & (df['year'] <= 1950) & (df['odometer'].isnull()),
                (df['year'] > 1950) & (df['year'] <= 1960) & (df['odometer'].isnull()),
                (df['year'] > 1960) & (df['year'] <= 1970) & (df['odometer'].isnull()),
                (df['year'] > 1970) & (df['year'] <= 1980) & (df['odometer'].isnull()),
                (df['year'] > 1980) & (df['year'] <= 1990) & (df['odometer'].isnull()),
                (df['year'] > 1990) & (df['year'] <= 2000) & (df['odometer'].isnull()),
                (df['year'] > 2000) & (df['year'] <= 2010) & (df['odometer'].isnull()),
                (df['year'] > 2010) & (df['year'] <= 2020) & (df['odometer'].isnull()),
                (df['year'] > 2020) & (df['odometer'].isnull())
]

choices = [
            int(od_decade_means.iloc[0,0]),
            int(od_decade_means.iloc[1,0]),
            int(od_decade_means.iloc[2,0]),
            int(od_decade_means.iloc[3,0]),
            int(od_decade_means.iloc[4,0]),
            int(od_decade_means.iloc[5,0]),
            int(od_decade_means.iloc[6,0]),
            int(od_decade_means.iloc[7,0]),
            int(od_decade_means.iloc[8,0]),
            int(od_decade_means.iloc[9,0]),
            int(od_decade_means.iloc[10,0]),
            int(od_decade_means.iloc[11,0]),
            int(od_decade_means.iloc[12,0])
]

df_clean['odometer'] = np.select(conditions, choices, default = df['odometer'])

# %%
plt.figure(figsize = (10,10))
sns.heatmap(df_clean.isnull(), cbar=False);

# %% [markdown]
# ### Impute Paint Color

# %%
paint_color_probs_dict = df_clean.groupby(by = ['manufacturer'])['paint_color'].value_counts(normalize = True).unstack().to_dict('index')

# %%
paint_color_probs_dict
# Out:
# {'acura': {'black': 0.24328593996840442,
#   'blue': 0.06714060031595577,
#   'brown': 0.0169826224328594,
#   'custom': 0.02330173775671406,
#   'green': 0.013033175355450236,
#   'grey': 0.17377567140600317,
#   'orange': 0.001184834123222749,
#   'purple': 0.0007898894154818325,
#   'red': 0.045813586097946286,
#   'silver': 0.18996840442338073,
#   'white': 0.22472353870458137,
#   'yellow': nan},
#  'alfa-romeo': {'black': 0.18181818181818182,
#   'blue': 0.09090909090909091,
#   'brown': nan,
#   'custom': nan,
#   'green': 0.05454545454545454,
#   'grey': 0.10909090909090909,
#   'orange': nan,
#   'purple': nan,
#   'red': 0.2545454545454545,
#   'silver': 0.03636363636363636,
#   'white': 0.2545454545454545,
#   'yellow': 0.01818181818181818},
#  'aston-martin': {'black': 0.22727272727272727,
#   'blue': 0.13636363636363635,
#   'brown': nan,
#   'custom': 0.045454545454545456,
#   'green': 0.22727272727272727,
#   'grey': 0.045454545454545456,
#   'orange': nan,
#   'purple': nan,
#   'red': 0.045454545454545456,
#   'silver': 0.2727272727272727,
#   'white': nan,
#   'yellow': nan},
#  'audi': {'black': 0.31353555952077494,
#   'blue': 0.11776701503951058,
#   'brown': 0.04205964822839663,
#   'custom': 0.010451185317359163,
#   'green': 0.0035686974254397143,
#   'grey': 0.15065001274534795,
#   'orange': 0.0025490695895997962,
#   'purple': 0.0005098139179199592,
#   'red': 0.03339281162375733,
#   'silver': 0.13790466479734897,
#   'white': 0.1863369869997451,
#   'yellow': 0.0012745347947998981},
#  'bmw': {'black': 0.30081659677775324,
#   'blue': 0.13672478481571396,
#   'brown': 0.014014566320900463,
#   'custom': 0.016773339218715516,
#   'green': 0.01169719708673582,
#   'grey': 0.13992496137717944,
#   'orange': 0.003862282056941073,
#   'purple': 0.0007724564113882145,
#   'red': 0.037960715073935114,
#   'silver': 0.14180092694769367,
#   'white': 0.19377620834252923,
#   'yellow': 0.0018759655705142353},
#  'buick': {'black': 0.14254683681781158,
#   'blue': 0.0795547108335596,
#   'brown': 0.09177301113222916,
#   'custom': 0.037469454249253326,
#   'green': 0.014933478142818354,
#   'grey': 0.07738256855824056,
#   'orange': 0.00027151778441487917,
#   'purple': 0.0029411764705882353,
#   'red': 0.13294117647058823,
#   'silver': 0.1588235294117647,
#   'white': 0.2576470588235294,
#   'yellow': 0.001176470588235294},
#  'morgan': {'black': nan,
#   'blue': 0.03125,
#   'brown': nan,
#   'custom': nan,
#   'green': nan,
#   'grey': 0.03125,
#   'orange': nan,
#   'purple': nan,
#   'red': nan,
#   'silver': nan,
#   'white': 0.8125,
#   'yellow': 0.125},
#  'nan': {'black': 0.15712468193384224,
#   'blue': 0.07442748091603053,
#   'brown': 0.012086513994910942,
#   'custom': 0.05916030534351145,
#   'green': 0.031806615776081425,
#   'grey': 0.05343511450381679,
#   'orange': 0.013994910941475827,
#   'purple': 0.004452926208651399,
#   'red': 0.06870229007633588,
#   'silver': 0.08078880407124682,
#   'white': 0.4243002544529262,
#   'yellow': 0.019720101781170483},
#  'nissan': {'black': 0.20979440148654319,
#   'blue': 0.09254930168434934,
#   'brown': 0.020320086315410896,
#   'custom': 0.02415632679973626,
#   'green': 0.008451717317029312,
#   'grey': 0.14050230773841635,
#   'orange': 0.0034166516813522747,
#   'purple': 0.0020380027572978483,
#   'red': 0.08187975783731943,
#   'silver': 0.19984415273032427,
#   'white': 0.2127315231073548,
#   'yellow': 0.004315770544866032},
#  'pontiac': {'black': 0.15670859538784068,
#   'blue': 0.11425576519916142,
#   'brown': 0.01781970649895178,
#   'custom': 0.027253668763102725,
#   'green': 0.03773584905660377,
#   'grey': 0.100104821802935,
#   'orange': 0.01519916142557652,
#   'purple': 0.007337526205450734,
#   'red': 0.1871069182389937,
#   'silver': 0.17243186582809225,
#   'white': 0.149895178197065,
#   'yellow': 0.014150943396226415},
#  'porche': {'black': 0.16666666666666666,
#   'blue': 0.08333333333333333,
#   'brown': 0.041666666666666664,
#   'custom': 0.041666666666666664,
#   'green': 0.08333333333333333,
#   'grey': 0.041666666666666664,
#   'orange': 0.041666666666666664,
#   'purple': nan,
#   'red': 0.08333333333333333,
#   'silver': 0.3333333333333333,
#   'white': 0.08333333333333333,
#   'yellow': nan},
#  'ram': {'black': 0.1784634414513469,
#   'blue': 0.0757284222100055,
#   'brown': 0.018141836173721827,
#   'custom': 0.023020890599230345,
#   'green': 0.01827927432655305,
#   'grey': 0.0820505772402419,
#   'orange': 0.004947773501924134,
#   'purple': 0.0015805387575590984,
#   'red': 0.11139362286970864,
#   'silver': 0.11208081363386477,
#   'white': 0.3691588785046729,
#   'yellow': 0.005153930731170973},
#  'rover': {'black': 0.3161993769470405,
#   'blue': 0.05996884735202492,
#   'brown': 0.020249221183800622,
#   'custom': 0.04439252336448598,
#   'green': 0.045171339563862926,
#   'grey': 0.08177570093457943,
#   'orange': 0.002336448598130841,
#   'purple': nan,
#   'red': 0.056074766355140186,
#   'silver': 0.07476635514018691,
#   'white': 0.29750778816199375,
#   'yellow': 0.001557632398753894},
#  'saturn': {'black': 0.15942028985507245,
#   'blue': 0.16996047430830039,
#   'brown': 0.025032938076416336,
#   'custom': 0.028985507246376812,
#   'green': 0.048748353096179184,
#   'grey': 0.10408432147562582,
#   'orange': 0.006587615283267457,
#   'purple': 0.007905138339920948,
#   'red': 0.11594202898550725,
#   'silver': 0.21080368906455862,
#   'white': 0.11725955204216074,
#   'yellow': 0.005270092226613966},
#  'subaru': {'black': 0.11944705408669977,
#   'blue': 0.2076231378338478,
#   'brown': 0.013957858005636828,
#   'custom': 0.027378875318749163,
#   'green': 0.06213931015971011,
#   'grey': 0.11850758287478191,
#   'orange': 0.0065762984834250434,
#   'purple': 0.0010736813850489868,
#   'red': 0.08052610387867401,
#   'silver': 0.19755737484901356,
#   'white': 0.16293115018118373,
#   'yellow': 0.0022815729432290968},
#  'tesla': {'black': 0.24521072796934865,
#   'blue': 0.16475095785440613,
#   'brown': 0.01532567049808429,
#   'custom': 0.019157088122605363,
#   'green': 0.011494252873563218,
#   'grey': 0.11877394636015326,
#   'orange': nan,
#   'purple': nan,
#   'red': 0.14942528735632185,
#   'silver': 0.05363984674329502,
#   'white': 0.2222222222222222,
#   'yellow': nan},
#  'toyota': {'black': 0.16089893262174784,
#   'blue': 0.10336057371581055,
#   'brown': 0.02163942628418946,
#   'custom': 0.029186124082721813,
#   'green': 0.03539859906604403,
#   'grey': 0.13463142094729819,
#   'orange': 0.00266844563042028,
#   'purple': 0.0014593062041360907,
#   'red': 0.09514676450967312,
#   'silver': 0.19854903268845897,
#   'white': 0.21280853902601735,
#   'yellow': 0.004252835223482321},
#  'volkswagen': {'black': 0.2293046357615894,
#   'blue': 0.13548565121412803,
#   'brown': 0.013520971302428256,
#   'custom': 0.017798013245033113,
#   'green': 0.01434878587196468,
#   'grey': 0.14693708609271522,
#   'orange': 0.004690949227373068,
#   'purple': 0.0011037527593818985,
#   'red': 0.07864238410596026,
#   'silver': 0.1586644591611479,
#   'white': 0.1886037527593819,
#   'yellow': 0.010899558498896247},
#  'volvo': {'black': 0.19342672413793102,
#   'blue': 0.1314655172413793,
#   'brown': 0.029633620689655173,
#   'custom': 0.017241379310344827,
#   'green': 0.03394396551724138,
#   'grey': 0.1314655172413793,
#   'orange': 0.005387931034482759,
#   'purple': 0.0010775862068965517,
#   'red': 0.0625,
#   'silver': 0.18911637931034483,
#   'white': 0.19827586206896552,
#   'yellow': 0.00646551724137931}}

# %%
rand_choice_paint_color_probs_dict = {}
for i in paint_color_probs_dict:
    colors_list = []
    probs_list = []
    for j in paint_color_probs_dict[i]: 
        if paint_color_probs_dict[i][j] > 0:
            colors_list.append(j)
            probs_list.append(paint_color_probs_dict[i][j])
#             temp_dict[j] = paint_color_probs_dict[i][j]
    rand_choice_paint_color_probs_dict[i] = {'colors': colors_list, 'probabilities': probs_list}
all_probs = df_clean['paint_color'].value_counts(normalize = True)
rand_choice_paint_color_probs_dict['all'] = {'colors': list(all_probs.index), 'probabilities': list(all_probs.values)}                           
rand_choice_paint_color_probs_dict
# Out:
# {'acura': {'colors': ['black',
#    'blue',
#    'brown',
#    'custom',
#    'green',
#    'grey',
#    'orange',
#    'purple',
#    'red',
#    'silver',
#    'white'],
#   'probabilities': [0.24328593996840442,
#    0.06714060031595577,
#    0.0169826224328594,
#    0.02330173775671406,
#    0.013033175355450236,
#    0.17377567140600317,
#    0.001184834123222749,
#    0.0007898894154818325,
#    0.045813586097946286,
#    0.18996840442338073,
#    0.22472353870458137]},
#  'alfa-romeo': {'colors': ['black',
#    'blue',
#    'green',
#    'grey',
#    'red',
#    'silver',
#    'white',
#    'yellow'],
#   'probabilities': [0
#    0.1486383989461148,
#    0.1013466310936055,
#    0.10096739209985296,
#    0.0969255028243325,
#    0.025212739768863814,
#    0.024118269339525353,
#    0.02178960885157118,
#    0.00692277496490376,
#    0.006676602284748604,
#    0.002398520302592797]}}

# %%
def rand_paint(row):
    key = row['manufacturer']
    if (type(row['paint_color']) == float) & (type(key) != float):
        return np.random.choice(rand_choice_paint_color_probs_dict[key]['colors'], 1, p=rand_choice_paint_color_probs_dict[key]['probabilities'])[0]
    elif (type(key) == float):
        return np.random.choice(rand_choice_paint_color_probs_dict['all']['colors'], 1, p=rand_choice_paint_color_probs_dict['all']['probabilities'])[0]
    return row['paint_color']


df_clean['paint_color'] = df_clean.apply(lambda x: rand_paint(x), axis = 1)

# %%
df_clean.isnull().sum()
# Out:
# id                   0
# url                  0
# region               0
# region_url           0
# price                0
# year              1117
# manufacturer      8372
# model             6199
# condition       186806
# cylinders       166384
# fuel              2991
# odometer            25
# title_status      1806
# transmission      2146
# vin             196652
# drive           122011
# size            295961
# type            117108
# paint_color          0
# image_url           24
# description         27
# county          435849
# state                0
# lat               8235
# long              8235
# age               1117
# dtype: int64

# %%
plt.figure(figsize = (10,10))
sns.heatmap(df_clean.isnull(), cbar=False);

# %%
final_paint_color_probs_dict = df_clean.groupby(by = ['manufacturer'])['paint_color'].value_counts(normalize = True).unstack().to_dict('index')

# %%
final_paint_color_probs_dict
# Out:
# {'acura': {'black': 0.2460431654676259,
#   'blue': 0.06935251798561151,
#   'brown': 0.015827338129496403,
#   'custom': 0.022158273381294964,
#   'green': 0.01553956834532374,
#   'grey': 0.1743884892086331,
#   'orange': 0.0008633093525179857,
#   'purple': 0.0005755395683453237,
#   'red': 0.04402877697841727,
#   'silver': 0.18762589928057555,
#   'white': 0.22359712230215828,
#   'yellow': nan},
#  'alfa-romeo': {'black': 0.16417910447761194,
#   'blue': 0.07462686567164178,
#   'brown': nan,
#   'custom': nan,
#   'green': 0.04477611940298507,
#   'grey': 0.08955223880597014,
#   'orange': nan,
#   'purple': nan,
#   'red': 0.2835820895522388,
#   'silver': 0.029850746268656716,
#   'white': 0.29850746268656714,
#   'yellow': 0.014925373134328358},
#  'aston-martin': {'black': 0.20588235294117646,
#   'blue': 0.14705882352941177,
#   'brown': nan,
#   'custom': 0.029411764705882353,
#   'green': 0.2647058823529412,
#   'grey': 0.029411764705882353,
#   'orange': nan,
#   'purple': nan,
#   'red': 0.058823529411764705,
#   'silver': 0.2647058823529412,
#   'white': nan,
#   'yellow': nan},
#  'audi': {'black': 0.3123319247022666,
#   'blue': 0.12043795620437957,
#   'brown': 0.040530157510564734,
#   'custom': 0.010180560891279293,
#   'green': 0.00384172109104879,
#   'grey': 0.15386092969650403,
#   'orange': 0.002305032654629274,
#   'purple': 0.0005762581636573184,
#   'red': 0.032078371110257395,
#   'silver': 0.13407606607760278,
#   'white': 0.1882443334613907,
#   'yellow': 0.001536688436419516},
#  'bmw': {'black': 0.30576773187841,
#   'blue': 0.13554169914263445,
#   'brown': 0.012938425565081839,
#   'custom': 0.016991426344505067,
#   'green': 0.01254871395167576,
#   'grey': 0.1383476227591582,
#   'orange': 0.0037412314886983633,
#   'purple': 0.0007014809041309431,
#   'red': 0.03710054559625877,
#   'silver': 0.14091971940763834,
#   'white': 0.19376461418550273,
#   'yellow': 0.0016367887763055339},
#   'green': 0.048580786026200876,
#   'grey': 0.08133187772925764,
#   'orange': 0.002183406113537118,
#   'purple': nan,
#   'red': 0.06331877729257641,
#   'silver': 0.07532751091703056,
#   'white': 0.2876637554585153,
#   'yellow': 0.001091703056768559},
#  'saturn': {'black': 0.15527426160337554,
#   'blue': 0.18227848101265823,
#   'brown': 0.026160337552742614,
#   'custom': 0.032067510548523206,
#   'green': 0.049789029535864976,
#   'grey': 0.10886075949367088,
#   'orange': 0.00590717299578059,
#   'purple': 0.007594936708860759,
#   'red': 0.10632911392405063,
#   'silver': 0.21434599156118145,
#   'white': 0.10632911392405063,
#   'yellow': 0.005063291139240506},
#  'subaru': {'black': 0.11906570451955943,
#   'blue': 0.20784276490695025,
#   'brown': 0.014337257880744398,
#   'custom': 0.0284846183061147,
#   'green': 0.061716672996581845,
#   'grey': 0.11982529434105584,
#   'orange': 0.006456513482719331,
#   'purple': 0.0009494872768704899,
#   'red': 0.07871249525256362,
#   'silver': 0.19521458412457274,
#   'white': 0.16502088872009116,
#   'yellow': 0.002373718192176225},
#  'tesla': {'black': 0.25609756097560976,
#   'blue': 0.16158536585365854,
#   'brown': 0.01524390243902439,
#   'custom': 0.018292682926829267,
#   'green': 0.012195121951219513,
#   'grey': 0.10365853658536585,
#   'orange': nan,
#   'purple': nan,
#   'red': 0.15853658536585366,
#   'silver': 0.04573170731707317,
#   'white': 0.22865853658536586,
#   'yellow': nan},
#  'toyota': {'black': 0.16158492942826877,
#   'blue': 0.1040968822468436,
#   'brown': 0.021930201265424148,
#   'custom': 0.028772653096281027,
#   'green': 0.03555784591600103,
#   'grey': 0.1348449712273469,
#   'orange': 0.00269117352343325,
#   'purple': 0.0014028457728535028,
#   'red': 0.09496406997051161,
#   'silver': 0.19782988347791233,
#   'white': 0.2119442297231527,
#   'yellow': 0.004380314351971141},
#  'volkswagen': {'black': 0.2287031469232311,
#   'blue': 0.13409500901984367,
#   'brown': 0.013830426939266387,
#   'custom': 0.01854078973742233,
#   'green': 0.014030867909400682,
#   'grey': 0.14421727801162557,
#   'orange': 0.0050110242533573865,
#   'purple': 0.0012026458208057728,
#   'red': 0.07847263980757667,
#   'silver': 0.15744638204048908,
#   'white': 0.19272399278412508,
#   'yellow': 0.011725796752856284},
#  'volvo': {'black': 0.1902639698320192,
#   'blue': 0.14055536510113129,
#   'brown': 0.028796708947548853,
#   'custom': 0.01576962632841961,
#   'green': 0.03222488858416181,
#   'grey': 0.12821391840932464,
#   'orange': 0.005827905382242029,
#   'purple': 0.0006856359273225917,
#   'red': 0.06307850531367844,
#   'silver': 0.18717860815906753,
#   'white': 0.20260541652382585,
#   'yellow': 0.0047994514912581415}}

# %% [markdown]
# Checking that the percentages of car colors stayed relatively the same before and after imputing

# %%
paint_color_probs_dict
# Out:
# {'acura': {'black': 0.24328593996840442,
#   'blue': 0.06714060031595577,
#   'brown': 0.0169826224328594,
#   'custom': 0.02330173775671406,
#   'green': 0.013033175355450236,
#   'grey': 0.17377567140600317,
#   'orange': 0.001184834123222749,
#   'purple': 0.0007898894154818325,
#   'red': 0.045813586097946286,
#   'silver': 0.18996840442338073,
#   'white': 0.22472353870458137,
#   'yellow': nan},
#  'alfa-romeo': {'black': 0.18181818181818182,
#   'blue': 0.09090909090909091,
#   'brown': nan,
#   'custom': nan,
#   'green': 0
#   'yellow': 0.006292606187729418},
#  'mazda': {'black': 0.18925964546402502,
#   'blue': 0.13660062565172054,
#   'brown': 0.013555787278415016,
#   'custom': 0.017726798748696558,
#   'green': 0.024504692387904068,
#   'grey': 0.1488529718456726,
#   'orange': 0.0031282586027111575,
#   'purple': 0.0072992700729927005,
#   'red': 0.145985401459854,
#   'silver': 0.1540667361835245,
#   'white': 0.15641293013555788,
#   'yellow': 0.0026068821689259644},
#  'mercedes-benz': {'black': 0.3300561797752809,
#   'blue': 0.07303370786516854,
#   'brown': 0.0125,
#   'custom': 0.0175561797752809,
#   'green': 0.012359550561797753,
#   'grey': 0.10561797752808989,
#   'orange': 0.0004213483146067416,
#   'purple': 0.0014044943820224719,
#   'red': 0.037219101123595506,
#   'silver': 0.1776685393258427,
#   'white': 0.2271067415730337,
#   'yellow': 0.0050561797752808986},
#  'mercury': {'black': 0.14774114774114774,
#   'blue': 0.11843711843711843,
#   'brown': 0.07326007326007326,
#   'custom': 0.047619047619047616,
#   'green': 0.0695970695970696,
#   'grey': 0.06837606837606838,
#   'orange': nan,
#   'purple': nan,
#   'red': 0.10500610500610501,
#   'silver': 0.19658119658119658,
#   'white': 0.1623931623931624,
#   'yellow': 0.01098901098901099},
#  'mini': {'black': 0.11625,
#   'blue': 0.1625,
#   'brown': 0.028125,
#   'custom': 0.0275,
#   'green': 0.075,
#   'grey': 0.091875,
#   'orange': 0.02,
#   'purple': 0.00125,
#   'red': 0.14875,
#   'silver': 0.078125,
#   'white': 0.22125,
#   'yellow': 0.029375},
#  'mitsubishi': {'black': 0.16647058823529412,
#   'blue': 0.11235294117647059,
#   'brown': 0.01647058823529412,
#   'custom': 0.010588235294117647,
#   'green': 0.019411764705882354,
#   'grey': 0.09647058823529411,
#   'orange': 0.024705882352941175,
#   'purple': 0.0029411764705882353,
#   'red': 0.13294117647058823,
#   'silver': 0.1588235294117647,
#   'white': 0.2576470588235294,
#   'yellow': 0.001176470588235294},
#  'morgan': {'black': nan,
#   'blue': 0.03125,
#   'brown': nan,
#   'custom': nan,
#   'green': nan,
#   'grey': 0.03125,
#   'orange': nan,
#   'purple': nan,
#   'red': nan,
#   'silver': nan,
#   'white': 0.8125,
#   'yellow': 0.125},
#  'nan': {'black': 0.15712468193384224,
#   'blue': 0.07442748091603053,
#   'brown': 0.012086513994910942,
#   'custom': 0.05916030534351145,
#   'green': 0.031806615776081425,
#   'grey': 0.05343511450381679,
#   'orange': 0.013994910941475827,
#   'purple': 0.004452926208651399,
#   'red': 0.06870229007633588,
#   'silver': 0.08078880407124682,
#   'white': 0.4243002544529262,
#   'yellow': 0.019720101781170483},
#  'nissan': {'black': 0.20979440148654319,
#   'blue': 0.09254930168434934,
#   'brown': 0.020320086315410896,
#   'custom': 0.02415632679973626,
#   'green': 0.008451717317029312,
#   'grey': 0.14050230773841635,
#   'orange': 0.0034166516813522747,
#   'purple': 0.0020380027572978483,
#   'red': 0.08187975783731943,
#   'silver': 0.19984415273032427,
#   'white': 0.2127315231073548,
#   'yellow': 0.004315770544866032},
#  'pontiac': {'black': 0.15670859538784068,
#   'blue': 0.11425576519916142,
#   'white': 0.21280853902601735,
#   'yellow': 0.004252835223482321},
#  'volkswagen': {'black': 0.2293046357615894,
#   'blue': 0.13548565121412803,
#   'brown': 0.013520971302428256,
#   'custom': 0.017798013245033113,
#   'green': 0.01434878587196468,
#   'grey': 0.14693708609271522,
#   'orange': 0.004690949227373068,
#   'purple': 0.0011037527593818985,
#   'red': 0.07864238410596026,
#   'silver': 0.1586644591611479,
#   'white': 0.1886037527593819,
#   'yellow': 0.010899558498896247},
#  'volvo': {'black': 0.19342672413793102,
#   'blue': 0.1314655172413793,
#   'brown': 0.029633620689655173,
#   'custom': 0.017241379310344827,
#   'green': 0.03394396551724138,
#   'grey': 0.1314655172413793,
#   'orange': 0.005387931034482759,
#   'purple': 0.0010775862068965517,
#   'red': 0.0625,
#   'silver': 0.18911637931034483,
#   'white': 0.19827586206896552,
#   'yellow': 0.00646551724137931}}

# %% [markdown]
# ### Dropping columns that didn't have a year or odometer value

# %% [markdown]
# difficult to impute accurately when they are both heavily correlated to the other and are both missing

# %%
df_clean[df_clean['odometer'].isnull()][['year', 'odometer']] #some cars have no year and odometer value
# Out:
#         year  odometer
# 28526    NaN       NaN
# 40969    NaN       NaN
# 74356    NaN       NaN
# 74400    NaN       NaN
# 80723    NaN       NaN
# 87185    NaN       NaN
# 87528    NaN       NaN
# 87633    NaN       NaN
# 89520    NaN       NaN
# 92583    NaN       NaN
# 96348    NaN       NaN
# 104415   NaN       NaN
# 115343   NaN       NaN
# 118183   NaN       NaN
# 140832   NaN       NaN
# 169941   NaN       NaN
# 170030   NaN       NaN
# 180343   NaN       NaN
# 204551   NaN       NaN
# 209685   NaN       NaN
# 284832   NaN       NaN
# 293879   NaN       NaN
# 319138   NaN       NaN
# 340835   NaN       NaN
# 345427   NaN       NaN

# %%
df_clean.dropna(subset = ['year'], inplace = True) # get rid of the 25 rows that have no value for year and odometer

# %% [markdown]
# ### Change VIN to a categorical value

# %%
df_clean['vin'] = df_clean['vin'].apply(lambda x: 0 if type(x) == float else 1) #replace vin column with binary yes/no column

# %%
df_clean.isnull().sum()
# Out:
# id                   0
# url                  0
# region               0
# region_url           0
# price                0
# year                 0
# manufacturer      8346
# model             6173
# condition       185692
# cylinders       166352
# fuel              2734
# odometer             0
# title_status      1583
# transmission      2122
# vin                  0
# drive           121823
# size            294847
# type            117013
# paint_color          0
# image_url            0
# description          3
# county          434732
# state                0
# lat               8211
# long              8211
# age                  0
# dtype: int64

# %% [markdown]
# ### Imputing fuel

# %%
condition = [
                (df_clean['description'].str.contains('diesel', case = False)) & (df_clean['fuel'].isnull()),
                (df_clean['description'].str.contains('hybrid', case = False)) & (df_clean['fuel'].isnull()),
                (df_clean['description'].str.contains('electric', case = False)) & (df_clean['fuel'].isnull())
]
choice = [
            'diesel',
            'hybrid',
            'electric'
]
df_clean['fuel'] = np.select(condition, choice, default = df_clean['fuel'])

# %%
df_clean.isnull().sum()
# Out:
# id                   0
# url                  0
# region               0
# region_url           0
# price                0
# year                 0
# manufacturer      8346
# model             6173
# condition       185692
# cylinders       166352
# fuel              2176
# odometer             0
# title_status      1583
# transmission      2122
# vin                  0
# drive           121823
# size            294847
# type            117013
# paint_color          0
# image_url            0
# description          3
# county          434732
# state                0
# lat               8211
# long              8211
# age                  0
# dtype: int64

# %% [markdown]
# ### Imputing the Drive type

# %%
df_clean['drive'].unique()
# Out:
# array([nan, 'rwd', '4wd', 'fwd'], dtype=object)

# %%
condition = [
                (df_clean['description'].str.contains('4wd', case = False)) & (df_clean['drive'].isnull()),
                (df_clean['description'].str.contains('fwd', case = False)) & (df_clean['drive'].isnull()),
                (df_clean['description'].str.contains('rwd', case = False)) & (df_clean['drive'].isnull())
]
choice = [
            '4wd',
            'fwd',
            'rwd'
]
df_clean['drive'] = np.select(condition, choice, default = df_clean['drive'])

# %%
df_clean.isnull().sum()
# Out:
# id                   0
# url                  0
# region               0
# region_url           0
# price                0
# year                 0
# manufacturer      8346
# model             6173
# condition       185692
# cylinders       166352
# fuel              2176
# odometer             0
# title_status      1583
# transmission      2122
# vin                  0
# drive           101348
# size            294847
# type            117013
# paint_color          0
# image_url            0
# description          3
# county          434732
# state                0
# lat               8211
# long              8211
# age                  0
# dtype: int64

# %%
drive_dict = df_clean.groupby(by = ['manufacturer'])['drive'].value_counts(normalize = True).unstack().to_dict('index')

# %%
rand_choice_drive_probs_dict = {}
for i in drive_dict:
    drive_list = []
    probs_list = []
    for j in drive_dict[i]: 
        if drive_dict[i][j] > 0:
            drive_list.append(j)
            probs_list.append(drive_dict[i][j])
    rand_choice_drive_probs_dict[i] = {'drive': drive_list, 'probabilities': probs_list}
all_probs = df_clean['drive'].value_counts(normalize = True)
rand_choice_drive_probs_dict['all'] = {'drive': list(all_probs.index), 'probabilities': list(all_probs.values)}                           
rand_choice_drive_probs_dict
# Out:
# {'acura': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.37490165224232885,
#    0.6038552321007081,
#    0.021243115656963022]},
#  'alfa-romeo': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.26785714285714285,
#    0.08928571428571429,
#    0.6428571428571429]},
#  'aston-martin': {'drive': ['rwd'], 'probabilities': [1.0]},
#  'audi': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.7837423312883436,
#    0.18312883435582822,
#    0.033128834355828224]},
#  'bmw': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.4036666666666667,
#    0.028555555555555556,
#    0.5677777777777778]},
#  'buick': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.18330087633885103,
#    0.7641187925998053,
#    0.05258033106134372]},
#  'cadillac': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.428664778915269,
#    0.2940535830973644,
#    0.2772816379873666]},
#  'chevrolet': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.4726311739332942,
#    0.29363520382333286,
#    0.23373362224337296]},
#  'chrysler': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.07355946056395586,
#    0.7360032693093584,
#    0.19043727012668574]},
#  'datsun': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.1320754716981132,
#    0.018867924528301886,
#    0.8490566037735849]},
#  'dodge': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.2340914899054434,
#    0.4384530198483687,
#    0.3274554902461879]},
#  'ferrari': {'drive': ['4wd', 'rwd'],
#   'probabilities': [0.1111111111111111, 0.8888888888888888]},
#  'fiat': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.020227560050568902,
#    0.8040455120101138,
#    0.17572692793931732]},
#  'ford': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.5368127933805394,
#    0.22347044315379108,
#    0.2397167634656695]},
#  'gmc': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.7427902308464369,
#    0.09648711943793911,
#    0.16072264971562394]},
#  'harley-davidson': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.7352941176470589, 0.014705882352941176, 0.25]},
#  'honda': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.2385304551740725,
#    0.7429499128134207,
#    0.018519632012506764]},
#  'hyundai': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.13472792927406302,
#    0.8104843730544141,
#    0.05478769767152285]},
#  'infiniti': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.4635436343029845,
#    0.11938043067623726,
#    0.4170759350207782]},
#  'jaguar': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.17717717717717718,
#    0.04354354354354354,
#    0.7792792792792793]},
#  'jeep': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.8591932830317127,
#    0.09644295682759403,
#    0.04436376014069326]},
#  'kia': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.12978449662270827,
#    0.842553875844323,
#    0.0276616275329688]},
#  'land rover': {'drive': ['4wd', 'rwd'],
#   'probabilities': [0.6842105263157895, 0.3157894736842105]},
#  'lexus': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.395067473243369,
#    0.3610981852024197,
#    0.24383434155421127]},
#  'lincoln': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.3725950258094791,
#    0.340215861098076,
#    0.2871891130924449]},
#  'mazda': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.15013671389510316,
#    0.6286353467561522,
#    0.2212279393487447]},
#  'mercedes-benz': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.4115295926210607,
#    0.053497309761721755,
#    0.5349730976172176]},
#  'mercury': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.27835051546391754,
#    0.3722794959908362,
#    0.34936998854524626]},
#  'mini': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.1157556270096463,
#    0.8263665594855305,
#    0.05787781350482315]},
#  'mitsubishi': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.35365183964854474,
#    0.5650741350906096,
#    0.08127402526084569]},
#  'morgan': {'drive': ['4wd', 'rwd'], 'probabilities': [0.04, 0.96]},
#  'nan': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.3512593601089176,
#    0.2498298162014976,
#    0.39891082368958475]},
#  'nissan': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.2980023113752683,
#    0.593638214737769,
#    0.10835947388696274]},
#  'pontiac': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.04734651404786681,
#    0.6201873048907388,
#    0.33246618106139436]},
#  'porche': {'drive': ['4wd', 'rwd'],
#   'probabilities': [0.2631578947368421, 0.7368421052631579]},
#  'ram': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.8005377789728422,
#    0.061037913417585375,
#    0.13842430760957247]},
#  'rover': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.9821300929235168,
#    0.01143674052894925,
#    0.006433166547533953]},
#  'saturn': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.12738095238095237,
#    0.7892857142857143,
#    0.08333333333333333]},
#  'subaru': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.9598059598059598,
#    0.01191961191961192,
#    0.028274428274428276]},
#  'tesla': {'drive': ['4wd', 'rwd'],
#   'probabilities': [0.36492890995260663, 0.6350710900473934]},
#  'toyota': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.40918690601900737,
#    0.5019359380499824,
#    0.08887715593101021]},
#  'volkswagen': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.10107015457788347,
#    0.8534813053243493,
#    0.04544854009776721]},
#  'volvo': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.4331348132106118,
#    0.5008121277747699,
#    0.0660530590146183]},
#  'all': {'drive': ['4wd', 'fwd', 'rwd'],
#   'probabilities': [0.4623557219302666,
#    0.3514625776881914,
#    0.186181700381542]}}

# %%
def impute_drive(row):
    key = row['manufacturer']
    if (type(row['drive']) == float) & (type(key) != float):
        return np.random.choice(rand_choice_drive_probs_dict[key]['drive'], 1, p=rand_choice_drive_probs_dict[key]['probabilities'])[0]
    elif (type(key) == float):
        return np.random.choice(rand_choice_drive_probs_dict['all']['drive'], 1, p=rand_choice_drive_probs_dict['all']['probabilities'])[0]
    return row['drive']


df_clean['drive'] = df_clean.apply(lambda x: impute_drive(x), axis = 1)

# %%
df_clean.isnull().sum()
# Out:
# id                   0
# url                  0
# region               0
# region_url           0
# price                0
# year                 0
# manufacturer      8346
# model             6173
# condition       185692
# cylinders       166352
# fuel              2176
# odometer             0
# title_status      1583
# transmission      2122
# vin                  0
# drive                0
# size            294847
# type            117013
# paint_color          0
# image_url            0
# description          3
# county          434732
# state                0
# lat               8211
# long              8211
# age                  0
# dtype: int64

# %% [markdown]
# ### Imputing the Transmission

# %%
((df_clean['description'].str.contains('manual', case = False)) & (df_clean['transmission'].isnull())).sum()
# Out:
# 169

# %%
condition = [
                (df_clean['description'].str.contains('manual', case = False)) & (df_clean['transmission'].isnull()),
                (df_clean['description'].str.contains('automatic', case = False)) & (df_clean['transmission'].isnull())
]
choice = [
            'manual',
            'automatic'
]
df_clean['transmission'] = np.select(condition, choice, default = df_clean['transmission'])

# %%
df_clean.isnull().sum()
# Out:
# id                   0
# url                  0
# region               0
# region_url           0
# price                0
# year                 0
# manufacturer      8346
# model             6173
# condition       185692
# cylinders       166352
# fuel              2176
# odometer             0
# title_status      1583
# transmission      1533
# vin                  0
# drive                0
# size            294847
# type            117013
# paint_color          0
# image_url            0
# description          3
# county          434732
# state                0
# lat               8211
# long              8211
# age                  0
# dtype: int64

# %% [markdown]
# ### Imputing the Cylinders

# %%
condition = [
                (df_clean['description'].str.contains('3 cyl', case = False)) & (df_clean['cylinders'].isnull()),
                (df_clean['description'].str.contains('4 cyl', case = False)) & (df_clean['cylinders'].isnull()),
                (df_clean['description'].str.contains('5 cyl', case = False)) & (df_clean['cylinders'].isnull()),
                (df_clean['description'].str.contains('6 cyl', case = False)) & (df_clean['cylinders'].isnull()),
                (df_clean['description'].str.contains('8 cyl', case = False)) & (df_clean['cylinders'].isnull()),
                (df_clean['description'].str.contains('10 cyl', case = False)) & (df_clean['cylinders'].isnull()),
                (df_clean['description'].str.contains('12 cyl', case = False)) & (df_clean['cylinders'].isnull()),
                (df_clean['description'].str.contains('3cyl', case = False)) & (df_clean['cylinders'].isnull()),
                (df_clean['description'].str.contains('4cyl', case = False)) & (df_clean['cylinders'].isnull()),
                (df_clean['description'].str.contains('5cyl', case = False)) & (df_clean['cylinders'].isnull()),
                (df_clean['description'].str.contains('6cyl', case = False)) & (df_clean['cylinders'].isnull()),
                (df_clean['description'].str.contains('8cyl', case = False)) & (df_clean['cylinders'].isnull()),
                (df_clean['description'].str.contains('10cyl', case = False)) & (df_clean['cylinders'].isnull()),
                (df_clean['description'].str.contains('12cyl', case = False)) & (df_clean['cylinders'].isnull())
    
    
]
choice = [
            '3 cylinders',
            '4 cylinders',
            '5 cylinders',
            '6 cylinders',
            '8 cylinders',
            '10 cylinders',
            '12 cylinders',
            '3 cylinders',
            '4 cylinders',
            '5 cylinders',
            '6 cylinders',
            '8 cylinders',
            '10 cylinders',
            '12 cylinders'
]
df_clean['cylinders'] = np.select(condition, choice, default = df_clean['cylinders'])

# %%
df_clean.isnull().sum()
# Out:
# id                   0
# url                  0
# region               0
# region_url           0
# price                0
# year                 0
# manufacturer      8346
# model             6173
# condition       185692
# cylinders       140477
# fuel              2176
# odometer             0
# title_status      1583
# transmission      1533
# vin                  0
# drive                0
# size            294847
# type            117013
# paint_color          0
# image_url            0
# description          3
# county          434732
# state                0
# lat               8211
# long              8211
# age                  0
# dtype: int64

# %%
cylinder_probs_dict = df_clean.groupby(by = ['manufacturer'])['cylinders'].value_counts(normalize = True).unstack().to_dict('index')

# %%
rand_choice_cylinders_probs_dict = {}
for i in cylinder_probs_dict:
    cylinder_list = []
    probs_list = []
    for j in cylinder_probs_dict[i]: 
        if cylinder_probs_dict[i][j] > 0:
            cylinder_list.append(j)
            probs_list.append(cylinder_probs_dict[i][j])
    rand_choice_cylinders_probs_dict[i] = {'cylinder': cylinder_list, 'probabilities': probs_list}
all_probs = df_clean['cylinders'].value_counts(normalize = True)
rand_choice_cylinders_probs_dict['all'] = {'cylinder': list(all_probs.index), 'probabilities': list(all_probs.values)}                           
rand_choice_cylinders_probs_dict
# Out:
# {'acura': {'cylinder': ['10 cylinders',
#    '12 cylinders',
#    '3 cylinders',
#    '4 cylinders',
#    '5 cylinders',
#    '6 cylinders',
#    '8 cylinders',
#    'other'],
#   'probabilities': [0.0007990411506192569,
#    0.007191370355573312,
#    0.00039952057530962844,
#    0.29604474630443467,
#    0.0015980823012385138,
#    0.6915701158609668,
#    0.0007990411506192569,
#    0.0015980823012385138]},
#  'alfa-romeo': {'cylinder': ['4 cylinders', '6 cylinders'],
#   'probabilities': [0.94, 0.06]},
#  'aston-martin': {'cylinder': ['12 cylinders', '6 cylinders', '8 cylinders'],
#   'probabilities': [0.875, 0.041666666666666664, 0.08333333333333333]},
#  'audi': {'cylinder': ['10 cylinders',
#    '12 cylinders',
#    '3 cylinders',
#    '4 cylinders',
#    '5 cylinders',
#    '6 cylinders',
#    '8 cylinders',
#    'other'],
#   'probabilities': [0.006030701754385965,
#    0.0013706140350877192,
#    0.004934210526315789,
#    0.5158991228070176,
#    0.005208333333333333,
#    0.36485745614035087,
#    0.09895833333333333,
#    0.0027412280701754384]},
#  'bmw': {'cylinder': ['10 cylinders',
#    '12 cylinders',
#    '3 cylinders',
#    '4 cylinders',
#    '5 cylinders',
#    '6 cylinders',
#    '8 cylinders',
#    'other'],
#   'probabilities': [0.009918319719953326,
#    0.0022170361726954494,
#    0.003267211201866978,
#    0.2394399066511085,
#    0.001633605600933489,
#    0.588681446907818,
#    0.1530921820303384,
#    0.001750291715285881]},
#  'buick': {'cylinder': ['3 cylinders',
#    '4 cylinders',
#    '5 cylinders',
#    '6 cylinders',
#    '8 cylinders',
#    'other'],
#   'probabilities': [0.
cylinders',
#    '3 cylinders',
#    '4 cylinders',
#    '5 cylinders',
#    '6 cylinders',
#    '8 cylinders',
#    'other'],
#   'probabilities': [0.00468384074941452,
#    0.00078064012490242,
#    0.19984387197501952,
#    0.00546448087431694,
#    0.26229508196721313,
#    0.5261514441842311,
#    0.00078064012490242]},
#  'saturn': {'cylinder': ['4 cylinders', '6 cylinders', '8 cylinders', 'other'],
#   'probabilities': [0.5840286054827175,
#    0.4135876042908224,
#    0.0011918951132300357,
#    0.0011918951132300357]},
#  'subaru': {'cylinder': ['10 cylinders',
#    '3 cylinders',
#    '4 cylinders',
#    '5 cylinders',
#    '6 cylinders',
#    '8 cylinders',
#    'other'],
#   'probabilities': [0.0012024048096192384,
#    0.0004008016032064128,
#    0.9326653306613226,
#    0.0013360053440213762,
#    0.06025384101536406,
#    0.0008016032064128256,
#    0.0033400133600534404]},
#  'tesla': {'cylinder': ['10 cylinders', '8 cylinders', 'other'],
#   'probabilities': [0.07936507936507936,
#    0.015873015873015872,
#    0.9047619047619048]},
#  'toyota': {'cylinder': ['10 cylinders',
#    '12 cylinders',
#    '3 cylinders',
#    '4 cylinders',
#    '5 cylinders',
#    '6 cylinders',
#    '8 cylinders',
#    'other'],
#   'probabilities': [0.0023137990186300715,
#    3.989308652810468e-05,
#    0.00039893086528104677,
#    0.4694219491762078,
#    0.0008377548170901983,
#    0.3750349064507121,
#    0.14987832608608928,
#    0.0020744404994614434]},
#  'volkswagen': {'cylinder': ['10 cylinders',
#    '3 cylinders',
#    '4 cylinders',
#    '5 cylinders',
#    '6 cylinders',
#    '8 cylinders',
#    'other'],
#   'probabilities': [0.0012001200120012002,
#    0.00075007500750075,
#    0.7565256525652565,
#    0.14596459645964596,
#    0.08355835583558356,
#    0.005700570057005701,
#    0.0063006300630063005]},
#  'volvo': {'cylinder': ['3 cylinders',
#    '4 cylinders',
#    '5 cylinders',
#    '6 cylinders',
#    '8 cylinders',
#    'other'],
#   'probabilities': [0.0005470459518599562,
#    0.24179431072210067,
#    0.3440919037199125,
#    0.3637855579868709,
#    0.039934354485776806,
#    0.009846827133479213]},
#  'all': {'cylinder': ['6 cylinders',
#    '4 cylinders',
#    '8 cylinders',
#    '5 cylinders',
#    '10 cylinders',
#    'other',
#    '3 cylinders',
#    '12 cylinders'],
#   'probabilities': [0.3513857028767566,
#    0.32573448199690747,
#    0.29940018011588587,
#    0.00952914988700277,
#    0.0060321829705527515,
#    0.003809620907036414,
#    0.0031197430799816484,
#    0.0009889381658765356]}}

# %%
def impute_cylinders(row):
    key = row['manufacturer']
    if (type(row['cylinders']) == float) & (type(key) != float):
        return np.random.choice(rand_choice_cylinders_probs_dict[key]['cylinder'], 1, p=rand_choice_cylinders_probs_dict[key]['probabilities'])[0]
    elif (type(key) == float):
        return np.random.choice(rand_choice_cylinders_probs_dict['all']['cylinder'], 1, p=rand_choice_cylinders_probs_dict['all']['probabilities'])[0]
    return row['cylinders']


df_clean['cylinders'] = df_clean.apply(lambda x: impute_cylinders(x), axis = 1)

# %%
df_clean.isnull().sum()
# Out:
# id                   0
# url                  0
# region               0
# region_url           0
# price                0
# year                 0
# manufacturer      8346
# model             6173
# condition       185692
# cylinders            0
# fuel              2176
# odometer             0
# title_status      1583
# transmission      1533
# vin                  0
# drive                0
# size            294847
# type            117013
# paint_color          0
# image_url            0
# description          3
# county          434732
# state                0
# lat               8211
# long              8211
# age                  0
# dtype: int64

# %% [markdown]
# ### Imputing the Car Size

# %%
df_clean['size'].unique()
# Out:
# array([nan, 'mid-size', 'full-size', 'sub-compact', 'compact'],
#       dtype=object)

# %%
df_clean.groupby(by = ['manufacturer', 'cylinders'])['size'].value_counts()
# Out:
# manufacturer     cylinders     size
# acura            10 cylinders  full-size          2
#                  4 cylinders   compact          152
#                                mid-size         124
#                                full-size         73
#                                sub-compact        6
#                  5 cylinders   compact            2
#                                full-size          1
#                                sub-compact        1
#                  6 cylinders   mid-size         355
#                                full-size        331
#                                compact          102
#                                sub-compact        6
#                  8 cylinders   full-size          1
#                                mid-size           1
# alfa-romeo       4 cylinders   compact           12
#                                full-size          8
#                                mid-size           5
#                                sub-compact        1
#                  6 cylinders   mid-size           3
# aston-martin     12 cylinders  full-size          3
#                                mid-size           1
#                                sub-compact        1
#                  8 cylinders   sub-compact        1
# audi             10 cylinders  full-size          6
#                                compact            2
#                                sub-compact        1
#                  12 cylinders  full-size          1
#                  3 cylinders   compact            2
#                                sub-compact        1
#                  4 cylinders   compact          309
#                                mid-size         241
#                                full-size        224
#                                sub-compact       82
#                  5 cylinders   mid-size           4
#                                compact            3
#                                full-size          3
#                  6 cylinders   full-size        264
#                                mid-size         209
#                                compact           84
#                                sub-compact       19
#                  8 cylinders   full-size         96
#                                mid-size          40
#                                compact           20
#                                sub-compact       10
#                  other         full-size          5
# bmw              10 cylinders  compact           15
#                                full-size         12
#                                sub-compact        8
#                                mid-size           7
#                  12 cylinders  full-size          8
#                                mid-size           2
#                                compact            1
#                  3 cylinders   sub-compact        6
#                                compact            3
#                                mid-size           2
#                  4 cylinders   compact          311
#                                mid-size         240
#                                full-size        198
#                                sub-compact       41
#                  5 cylinders   mid-size           9
#                                full-size          3
#                  6 cylinders   mid-size         987
#                                full-size        706
#                                compact          633
#                                sub-compact      139
#                  8 cylinders   full-size        376
#                                mid-size         149
#                                compact           61
#                                sub-compact       26
#                  other         compact            4
#                                full-size          2
#                                sub-compact        1
# buick            3 cylinders   compact            2
#                                full-size          1
#                                sub-compact        1
#                  4 cylinders   mid-size         147
#                                compact          143
#                                full-size         81
#                                sub-compact       13
#                  5 cylinders   compact            2
#                                full-size          2
#                  6 cylinders   full-size        722
#                                mid-size         404
#                                compact           29
#                                sub-compact        2
#                  8 cylinders   full-size        132
#                                mid-size          20
#                                compact            3
#                                sub-compact        1
# cadillac         3 cylinders   full-size          3
#                  4 cylinders   compact           61
#                                mid-size          55
#                                full-size         34
#                                sub-compact        1
#                  5 cylinders   full-size          3
#                                mid-size           1
#                  6 cylinders   full-size        395
#                                mid-size         315
#                                compact           31
#                                sub-compact        3
#                  8 cylinders   full-size       1074
#                                mid-size          69
#                                compact           29
#                                sub-compact        1
#                  other         full-size          3
# chevrolet        10 cylinders  mid-size          14
#                                compact            5
#                                full-size          5
#                  12 cylinders  sub-compact        7
#                                full-size          1
#                  3 cylinders   full-size          5
#                                compact            4
#                  4 cylinders   mid-size        1861
#                                compact         1462
#                                full-size        968
#                                sub-compact      180
#                  5 cylinders   mid-size          85
#                                full-size         54
#                                compact           14
#                                sub-compact        2
#                  6 cylinders   full-size       2406
#                                mid-size        1445
#                                compact          208
#                                sub-compact       21
#                  8 cylinders   full-size      10233
#                                mid-size        1150
#                                compact          404
#                                sub-compact       86
#                  other         full-size         29
#                                compact            9
#                                mid-size           7
#                                sub-compact        1
# chrysler         4 cylinders   mid-size         322
#                                full-size        156
#                                compact          134
#                                sub-compact       15
#                  5 cylinders   full-size          1
#                  6 cylinders   full-size        832
#                                mid-size         558
#                                compact           93
#                                sub-compact        8
#                  8 cylinders   full-size        155
#                                mid-size          22
#                                compact           11
#                  other         full-size          2
#                                mid-size           2
# datsun           4 cylinders   compact            6
#                                sub-compact        1
#                  6 cylinders   compact            8
#                                mid-size           7
#                  8 cylinders   compact            1
#                                sub-compact        1
# dodge            10 cylinders  mid-size          19
#                                compact           12
#                                full-size          3
#                  12 cylinders  full-size          1
#                  3 cylinders   mid-size           3
#                                full-size          1
#                  4 cylinders   full-size        391
#                                mid-size         368
#                                compact          177
#                                sub-compact       12
#                  5 cylinders   full-size         30
#                                mid-size           7
#                                compact            5
#                  6 cylinders   full-size       1535
#                                mid-size         976
#                                compact           81
#                                sub-compact        8
#                  8 cylinders   full-size        817
#                                mid-size         305
#                                compact           36
#                                sub-compact        5
#                  other         full-size          2
#                                mid-size           2
#                                compact            1
# ferrari          12 cylinders  full-size          4
#                                sub-compact        1
#                  6 cylinders   full-size          2
#                                compact            1
#                  8 cylinders   compact            7
#                                mid-size           7
#                                full-size          3
#                                sub-compact        1
# fiat             3 cylinders   compact            1
#                  4 cylinders   compact          165
#                                sub-compact       94
#                                mid-size          23
#                                full-size         13
#                  6 cylinders   full-size          1
#                  other         sub-compact        7
#                                compact            4
#                                mid-size           2
# ford             10 cylinders  full-size        671
#                                mid-size          15
#                                compact           11
#                                sub-compact        2
#                  12 cylinders  full-size          1
#                                mid-size           1
#                  3 cylinders   compact           24
#                                full-size         11
#                                mid-size           7
#                                sub-compact        4
#                  4 cylinders   mid-size        2062
#                                compact         1502
#                                full-size       1143
#                                sub-compact      248
#                  5 cylinders   full-size         20
#                                mid-size           4
#                                compact            3
#                  6 cylinders   full-size       4661
#                                mid-size        2288
#                                compact          329
#                                sub-compact      166
#                  8 cylinders   full-size      11803
#                                mid-size         888
#                                compact          280
#                                sub-compact      192
#                  other         full-size         49
#                                mid-size          10
#                                compact            5
#                                sub-compact        3
# gmc              10 cylinders  full-size          1
#                  4 cylinders   mid-size         198
#                                full-size        145
#                                compact           56
#                                sub-compact        4
#                  5 cylinders   mid-size          32
#                                full-size         27
#                                compact            2
#                                sub-compact        1
#                  6 cylinders   full-size        744
#                                mid-size         340
#                                compact           21
#                                sub-compact        1
#                  8 cylinders   full-size       4076
#                                mid-size         275
#                                compact           31
#                                sub-compact        6
#                  other         full-size          9
# harley-davidson  8 cylinders   full-size         29
#                                compact            1
#                                mid-size           1
#                  other         sub-compact        1
# honda            10 cylinders  full-size          4
#                                mid-size           3
#                                compact            2
#                  12 cylinders  compact            1
#                                full-size          1
#                  3 cylinders   compact           12
#                                sub-compact        9
#                                full-size          2
#                  4 cylinders   mid-size        1992
#                                compact         1818
#                                full-size       1307
#                                sub-compact      259
#                  5 cylinders   compact            5
#                                mid-size           2
#                                full-size          1
#                  6 cylinders   full-size       1498
#                                mid-size         743
#                                compact          172
#                                sub-compact       28
#                  8 cylinders   full-size         10
#                                mid-size           1
#                  other         compact            5
#                                full-size          3
#                                mid-size           2
#                                sub-compact        1
# hyundai          10 cylinders  compact            8
#                  3 cylinders   compact            2
#                  4 cylinders   mid-size         978
#                                compact          844
#                                full-size        831
#                                sub-compact       72
#                  5 cylinders   mid-size           1
#                  6 cylinders   full-size        337
#                                mid-size         307
#                                compact           70
#                                sub-compact        9
#                  8 cylinders   full-size         25
#                                compact            3
#                                mid-size           2
#                  other         full-size          2
# infiniti         10 cylinders  compact           10
#                                mid-size           5
#                                full-size          1
#                  4 cylinders   mid-size          14
#                                compact            6
#                                full-size          4
#                                sub-compact        1
#                  5 cylinders   compact            1
#                  6 cylinders   full-size        331
#                                mid-size         314
#                                compact          123
#                                sub-compact       41
#                  8 cylinders   full-size        169
#                                mid-size          16
#                                compact            2
#                                sub-compact        1
#                  other         mid-size           1
# jaguar           12 cylinders  compact            6
#                                full-size          5
#                                mid-size           4
#                                sub-compact        2
#                  4 cylinders   compact            4
#                                full-size          4
#                                mid-size           4
#                                sub-compact        3
#                  6 cylinders   full-size         83
#                                mid-size          53
#                                compact           22
#                                sub-compact        6
#                  8 cylinders   full-size        114
#                                mid-size          55
#                                sub-compact       23
#                                compact           20
# jeep             10 cylinders  full-size         14
#                  3 cylinders   full-size          2
#                                mid-size           1
#                  4 cylinders   mid-size         536
#                                compact          334
#                                full-size        322
#                                sub-compact       19
#                  5 cylinders   full-size          4
#                                mid-size           2
#                  6 cylinders   mid-size        1766
#                                full-size       1722
#                                compact          214
#                                sub-compact       24
#                  8 cylinders   full-size        357
#                                mid-size         269
#                                compact           18
#                                sub-compact        4
#                  other         mid-size           6
#                                full-size          1
#                                sub-compact        1
# kia              3 cylinders   compact            2
#                  4 cylinders   mid-size         794
#                                compact          690
#                                full-size        424
#                                sub-compact       37
#                  5 cylinders   mid-size           2
#                                sub-compact        1
#                  6 cylinders   full-size        286
#                                mid-size         250
#                                compact           32
#                  8 cylinders   full-size         11
#                                mid-size           3
#                                compact            1
#                  other         compact            1
# land rover       6 cylinders   compact            5
#                                full-size          1
#                  8 cylinders   full-size          4
#                                mid-size           2
#                                sub-compact        1
# lexus            10 cylinders  mid-size           6
#                                compact            5
#                                full-size          3
#                  4 cylinders   compact           37
#                                mid-size          36
#                                full-size         26
#                                sub-compact       10
#                  6 cylinders   mid-size         582
#                                full-size        497
#                                compact          126
#                                sub-compact       74
#                  8 cylinders   full-size        298
#                                mid-size          72
#                                compact           26
#                                sub-compact       12
# lincoln          12 cylinders  full-size          2
#                  4 cylinders   full-size         36
#                                mid-size          26
#                                compact            7
#                  5 cylinders   full-size          2
#                  6 cylinders   full-size        236
#                                mid-size         189
#                                compact            6
#                  8 cylinders   full-size        508
#                                mid-size          41
#                                compact            2
#                                sub-compact        2
# mazda            3 cylinders   compact            2
#                                full-size          1
#                  4 cylinders   compact          607
#                                mid-size         487
#                                full-size        211
#                                sub-compact       72
#                  5 cylinders   full-size          2
#                                mid-size           1
#                  6 cylinders   mid-size         128
#                                full-size         94
#                                compact           21
#                                sub-compact        1
#                  8 cylinders   full-size          3
#                  other         compact           14
#                                mid-size           2
#                                full-size          1
# mercedes-benz    10 cylinders  mid-size           7
#                                full-size          2
#                  12 cylinders  full-size         13
#                                compact            3
#                                mid-size           2
#                  3 cylinders   sub-compact        1
#                  4 cylinders   compact          218
#                                full-size        158
#                                mid-size         151
#                                sub-compact       24
#                  5 cylinders   full-size         24
#                                mid-size           7
#                                compact            2
#                  6 cylinders   full-size        705
#                                mid-size         628
#                                compact          264
#                                sub-compact       36
#                  8 cylinders   full-size        596
#                                mid-size         214
#                                compact          124
#                                sub-compact       13
#                  other         mid-size           3
#                                compact            1
#                                full-size          1
#                                sub-compact        1
# mercury          3 cylinders   mid-size           1
#                  4 cylinders   mid-size          34
#                                full-size         23
#                                compact            9
#                                sub-compact        3
#                  5 cylinders   mid-size           2
#                                full-size          1
#                  6 cylinders   mid-size         114
#                                full-size        103
#                                compact           18
#                                sub-compact        1
#                  8 cylinders   full-size        200
#                                mid-size          46
#                                compact            3
#                                sub-compact        1
# mini             10 cylinders  compact            1
#                  3 cylinders   compact           30
#                                sub-compact       30
#                                mid-size           5
#                                full-size          2
#                  4 cylinders   compact          405
#                                sub-compact      147
#                                mid-size          68
#                                full-size         33
#                  6 cylinders   full-size         34
#                                compact            9
#                                mid-size           7
#                                sub-compact        4
#                  8 cylinders   full-size         19
#                                compact            2
#                                mid-size           1
#                                sub-compact        1
#                  other         full-size          1
#                                sub-compact        1
# mitsubishi       3 cylinders   compact           45
#                                sub-compact       15
#                                full-size          6
#                                mid-size           5
#                  4 cylinders   mid-size         198
#                                compact          188
#                                full-size        150
#                                sub-compact       29
#                  5 cylinders   full-size          2
#                  6 cylinders   mid-size          74
#                                full-size         73
#                                compact           33
#                                sub-compact       13
#                  8 cylinders   full-size          6
#                                compact            1
#                                sub-compact        1
#                  other         compact            3
# morgan           4 cylinders   full-size          4
#                  6 cylinders   full-size         13
#                  8 cylinders   full-size          3
# nan              10 cylinders  full-size          6
#                  12 cylinders  full-size          5
#                                mid-size           4
#                                compact            2
#                  3 cylinders   compact            2
#                  4 cylinders   mid-size          66
#                                compact           57
#                                full-size         40
#                                sub-compact       11
#                  5 cylinders   full-size         33
#                                mid-size          15
#                  6 cylinders   full-size        137
#                                mid-size          47
#                                compact           30
#                                sub-compact        7
#                  8 cylinders   full-size        120
#                                mid-size          10
#                                compact            7
#                                sub-compact        4
#                  other         full-size          5
#                                compact            1
#                                mid-size           1
# nissan           10 cylinders  compact           10
#                                full-size          2
#                  12 cylinders  mid-size           1
#                  3 cylinders   full-size          2
#                  4 cylinders   mid-size        1708
#                                compact         1087
#                                full-size        996
#                                sub-compact       96
#                  5 cylinders   mid-size           3
#                                full-size          2
#                                compact            1
#                                sub-compact        1
#                  6 cylinders   full-size       1102
#                                mid-size        1072
#                                compact          248
#                                sub-compact       25
#                  8 cylinders   full-size        603
#                                mid-size          51
#                                compact           26
#                                sub-compact        4
#                  other         compact           27
#                                full-size          6
#                                mid-size           6
#                                sub-compact        4
# pontiac          4 cylinders   compact          129
#                                mid-size         118
#                                sub-compact       24
#                                full-size         22
#                  5 cylinders   sub-compact        1
#                  6 cylinders   mid-size         278
#                                full-size        180
#                                compact           90
#                                sub-compact        5
#                  8 cylinders   full-size        105
#                                mid-size          92
#                                compact           25
#                                sub-compact        8
#                  other         mid-size           3
# porche           4 cylinders   compact            2
#                                full-size          2
#                  6 cylinders   full-size          3
#                                compact            1
#                  8 cylinders   full-size          1
# ram              10 cylinders  full-size         39
#                                compact            4
#                  12 cylinders  mid-size           2
#                                full-size          1
#                                sub-compact        1
#                  3 cylinders   compact            7
#                                full-size          1
#                                sub-compact        1
#                  4 cylinders   mid-size          49
#                                compact           48
#                                full-size         45
#                                sub-compact        6
#                  5 cylinders   full-size         12
#                  6 cylinders   full-size       2421
#                                mid-size          91
#                                compact           29
#                                sub-compact       12
#                  8 cylinders   full-size       3082
#                                mid-size         225
#                                compact           15
#                                sub-compact        6
#                  other         full-size         18
#                                compact            4
#                                sub-compact        3
#                                mid-size           1
# rover            10 cylinders  full-size          4
#                  4 cylinders   full-size         47
#                                mid-size          27
#                                compact           12
#                                sub-compact        3
#                  6 cylinders   full-size         54
#                                mid-size          40
#                                compact            1
#                  8 cylinders   full-size        281
#                                mid-size          37
#                                compact            6
#                  other         compact            1
# saturn           4 cylinders   mid-size         122
#                                compact          112
#                                full-size         18
#                                sub-compact        9
#                  6 cylinders   mid-size         119
#                                full-size         74
#                                compact           22
#                                sub-compact        2
# subaru           10 cylinders  compact            9
#                  3 cylinders   compact            1
#                                mid-size           1
#                  4 cylinders   mid-size        1478
#                                compact          770
#                                full-size        713
#                                sub-compact       99
#                  5 cylinders   full-size          3
#                                mid-size           3
#                                compact            1
#                  6 cylinders   mid-size         113
#                                full-size         53
#                                compact           24
#                                sub-compact        2
#                  8 cylinders   full-size          1
#                                mid-size           1
#                  other         full-size          3
#                                compact            1
# tesla            10 cylinders  compact            5
#                  8 cylinders   full-size          1
#                  other         full-size         56
#                                mid-size          11
#                                compact            9
# toyota           10 cylinders  compact           16
#                                full-size          4
#                                mid-size           3
#                  12 cylinders  full-size          1
#                  3 cylinders   compact            2
#                                mid-size           1
#                  4 cylinders   mid-size        2320
#                                compact         1798
#                                full-size       1351
#                                sub-compact      137
#                  5 cylinders   mid-size           5
#                                full-size          2
#                  6 cylinders   full-size       1905
#                                mid-size        1798
#                                compact          255
#                                sub-compact       25
#                  8 cylinders   full-size       1361
#                                mid-size         115
#                                compact           33
#                                sub-compact        7
#                  other         compact            8
#                                full-size          7
#                                mid-size           4
#                                sub-compact        1
# volkswagen       10 cylinders  full-size          2
#                                compact            1
#                  3 cylinders   compact            2
#                                sub-compact        1
#                  4 cylinders   compact         1200
#                                mid-size        1027
#                                full-size        462
#                                sub-compact       76
#                  5 cylinders   compact          209
#                                mid-size         140
#                                full-size         97
#                                sub-compact       20
#                  6 cylinders   full-size        144
#                                mid-size          72
#                                compact           42
#                                sub-compact        3
#                  8 cylinders   full-size         15
#                                compact            5
#                                mid-size           4
#                                sub-compact        2
#                  other         full-size         20
#                                compact            8
#                                mid-size           2
# volvo            4 cylinders   mid-size          68
#                                compact           48
#                                full-size         35
#                                sub-compact        3
#                  5 cylinders   mid-size         150
#                                full-size        131
#                                compact           73
#                                sub-compact        8
#                  6 cylinders   full-size        224
#                                mid-size         116
#                                compact           18
#                                sub-compact        4
#                  8 cylinders   full-size         26
#                                mid-size           7
#                                compact            1
#                  other         compact            1
#                                full-size          1
# Name: size, dtype: int64

# %%
condition = [
                (df_clean['description'].str.contains('full-size', case = False)) & (df_clean['size'].isnull()),
                (df_clean['description'].str.contains('full size', case = False)) & (df_clean['size'].isnull()),
                (df_clean['description'].str.contains('fullsize', case = False)) & (df_clean['size'].isnull()),
                (df_clean['description'].str.contains('mid-size', case = False)) & (df_clean['size'].isnull()),
                (df_clean['description'].str.contains('mid size', case = False)) & (df_clean['size'].isnull()),
                (df_clean['description'].str.contains('midsize', case = False)) & (df_clean['size'].isnull()),
                (df_clean['description'].str.contains('sub-compact', case = False)) & (df_clean['size'].isnull()),
                (df_clean['description'].str.contains('sub compact', case = False)) & (df_clean['size'].isnull()),
                (df_clean['description'].str.contains('subcompact', case = False)) & (df_clean['size'].isnull()),
                (df_clean['description'].str.contains('compact', case = False)) & (df_clean['size'].isnull())
    
]
choice = [
            'full-size',
            'full-size',
            'full-size',
            'mid-size',
            'mid-size',
            'mid-size',
            'sub-compact',
            'sub-compact',
            'sub-compact',
            'compact'
]
df_clean['size'] = np.select(condition, choice, default = df_clean['size'])

# %%
df_clean.isnull().sum()
# Out:
# id                   0
# url                  0
# region               0
# region_url           0
# price                0
# year                 0
# manufacturer      8346
# model             6173
# condition       185692
# cylinders            0
# fuel              2176
# odometer             0
# title_status      1583
# transmission      1533
# vin                  0
# drive                0
# size            266016
# type            117013
# paint_color          0
# image_url            0
# description          3
# county          434732
# state                0
# lat               8211
# long              8211
# age                  0
# dtype: int64

# %% [markdown]
# ### Imputing Vehicle Type

# %%
df_clean['type'].unique()
# Out:
# array([nan, 'sedan', 'pickup', 'convertible', 'truck', 'van', 'SUV',
#        'coupe', 'mini-van', 'hatchback', 'offroad', 'wagon', 'other',
#        'bus'], dtype=object)

# %%
condition = [
                (df_clean['description'].str.contains('sedan', case = False)) & (df_clean['type'].isnull()),
                (df_clean['description'].str.contains('pickup', case = False)) & (df_clean['type'].isnull()),
                (df_clean['description'].str.contains('convertible', case = False)) & (df_clean['type'].isnull()),
                (df_clean['description'].str.contains('truck', case = False)) & (df_clean['type'].isnull()),
                (df_clean['description'].str.contains('van', case = False)) & (df_clean['type'].isnull()),
                (df_clean['description'].str.contains('SUV', case = False)) & (df_clean['type'].isnull()),
                (df_clean['description'].str.contains('coupe', case = False)) & (df_clean['type'].isnull()),
                (df_clean['description'].str.contains('mini-van', case = False)) & (df_clean['type'].isnull()),
                (df_clean['description'].str.contains('hatchback', case = False)) & (df_clean['type'].isnull()),
                (df_clean['description'].str.contains('offroad', case = False)) & (df_clean['type'].isnull()),
                (df_clean['description'].str.contains('wagon', case = False)) & (df_clean['type'].isnull()),
                (df_clean['description'].str.contains('bus', case = False)) & (df_clean['type'].isnull())
   
    
    
]
choice = [
            'sedan',
            'pickup',
            'convertible',
            'truck',
            'van',
            'SUV',
            'coupe',
            'mini-van',
            'hatchback',
            'offroad',
            'wagon',
            'bus'
]
df_clean['type'] = np.select(condition, choice, default = df_clean['type'])

# %%
type_probs_dict = df_clean.groupby(by = ['manufacturer'])['type'].value_counts(normalize = True).unstack().to_dict('index')

# %%
rand_choice_type_probs_dict = {}
for i in type_probs_dict:
    type_list = []
    probs_list = []
    for j in type_probs_dict[i]: 
        if type_probs_dict[i][j] > 0:
            type_list.append(j)
            probs_list.append(type_probs_dict[i][j])
    rand_choice_type_probs_dict[i] = {'type': type_list, 'probabilities': probs_list}
all_probs = df_clean['type'].value_counts(normalize = True)
rand_choice_type_probs_dict['all'] = {'type': list(all_probs.index), 'probabilities': list(all_probs.values)}                           
rand_choice_type_probs_dict
# Out:
# {'acura': {'type': ['SUV',
#    'bus',
#    'convertible',
#    'coupe',
#    'hatchback',
#    'mini-van',
#    'other',
#    'pickup',
#    'sedan',
#    'truck',
#    'van',
#    'wagon'],
#   'probabilities': [0.36863543788187375,
#    0.004073319755600814,
#    0.0016972165648336728,
#    0.03767820773930754,
#    0.012219959266802444,
#    0.00033944331296673454,
#    0.02308214528173795,
#    0.0006788866259334691,
#    0.49626612355736593,
#    0.014596062457569586,
#    0.03428377460964019,
#    0.006449422946367957]},
#  'alfa-romeo': {'type': ['SUV',
#    'bus',
#    'convertible',
#    'coupe',
#    'other',
#    'sedan',
#    'van'],
#   'probabilities': [0.2,
#    0.015384615384615385,
#    0.35384615384615387,
#    0.09230769230769231,
#    0.015384615384615385,
#    0.3076923076923077,
#    0.015384615384615385]},
#  'aston-martin': {'type': ['convertible', 'coupe', 'sedan'],
#   'probabilities': [0.5, 0.46875, 0.03125]},
#  'audi': {'type': ['SUV',
#    'bus',
#    'convertible',
#    'coupe',
#    'hatchback',
#    'offroad',
#    'other',
#    'pickup',
#    'sedan',
#    'truck',
#    'van',
#    'wagon'],
#   'probabilities': [0
#    0.008079008890090491,
#    0.002003848661715358]}}

# %%
def impute_type(row):
    key = row['manufacturer']
    if (type(row['type']) == float) & (type(key) != float):
        return np.random.choice(rand_choice_type_probs_dict[key]['type'], 1, p=rand_choice_type_probs_dict[key]['probabilities'])[0]
    elif (type(key) == float):
        return np.random.choice(rand_choice_type_probs_dict['all']['type'], 1, p=rand_choice_type_probs_dict['all']['probabilities'])[0]
    return row['type']


df_clean['type'] = df_clean.apply(lambda x: impute_type(x), axis = 1)

# %% [markdown]
# ### Imputing Vehicle Condition

# %%
excellent_odo_mean = df_clean[df_clean['condition'] == 'excellent']['odometer'].mean()
good_odo_mean = df_clean[df_clean['condition'] == 'good']['odometer'].mean()
like_new_odo_mean = df_clean[df_clean['condition'] == 'like new']['odometer'].mean()
salvage_odo_mean = df_clean[df_clean['condition'] == 'salvage']['odometer'].mean()
fair_odo_mean = df_clean[df_clean['condition'] == 'fair']['odometer'].mean()
print('excelent {}, good {}, like_new {}, salvage {}, fair {}'.format(excellent_odo_mean, good_odo_mean,
                                                                like_new_odo_mean, salvage_odo_mean,
                                                                fair_odo_mean))
# Out:
# excelent 104968.78537656197, good 107567.22591560087, like_new 80815.46236052745, salvage 146100.56142857144, fair 167217.83775641944

# %%
df_clean.loc[df_clean['odometer'] <= like_new_odo_mean, 'condition'] = df_clean.loc[df_clean['odometer'] <= like_new_odo_mean, 'condition'].fillna('like new')
df_clean.loc[df_clean['odometer'] >= fair_odo_mean, 'condition'] = df_clean.loc[df['odometer'] >= fair_odo_mean, 'condition'].fillna('fair')
df_clean.loc[((df_clean['odometer'] > like_new_odo_mean) & 
       (df_clean['odometer'] <= excellent_odo_mean)), 'condition'] = df_clean.loc[((df_clean['odometer'] > like_new_odo_mean) & 
       (df_clean['odometer'] <= excellent_odo_mean)), 'condition'].fillna('excellent')
df_clean.loc[((df_clean['odometer'] > excellent_odo_mean) & 
       (df_clean['odometer'] <= good_odo_mean)), 'condition'] = df_clean.loc[((df_clean['odometer'] > excellent_odo_mean) & 
       (df_clean['odometer'] <= good_odo_mean)), 'condition'].fillna('good')
df_clean.loc[((df_clean['odometer'] > good_odo_mean) & 
       (df_clean['odometer'] <= fair_odo_mean)), 'condition'] = df_clean.loc[((df_clean['odometer'] > good_odo_mean) & 
       (df_clean['odometer'] <= fair_odo_mean)), 'condition'].fillna('salvage')

# %% [markdown]
# ### Miscellaneous

# %% [markdown]
# '$500 DOWN PROGRAMS!!!','Most Cars Under $4000!', 'SPECIAL FINANCE PROGRAM 2020', 'USED', 'All' Noticed these were in model column

# %% [markdown]
# ### Removing price outliers

# %%
plt.figure(figsize = (20,10))
df_clean[(df_clean['price'] < 60000) & (df_clean['price'] > 500)]['price'].hist(bins = 240)
# plt.xticks(list(np.linspace(0,60000,60)));

# %% [markdown]
# Decided to limit our observations to prices between 500 and 60,000 dollars. 500 was picked as our lower limit because we noticed that a lot of prices under this value were for monthly installments. We picked 60,000 as our upper limit to remove outliers and a small percentage of of our data was greater than 60,000.

# %%
df_clean[(df_clean['price'] < 60000) & (df_clean['price'] > 500)].shape
# Out:
# (392466, 26)

# %%
df_clean.shape
# Out:
# (434732, 26)

# %%
df_clean = df_clean[(df_clean['price'] < 60000) & (df_clean['price'] > 500)].copy()

# %%
df_clean.isnull().sum()
# Out:
# id                   0
# url                  0
# region               0
# region_url           0
# price                0
# year                 0
# manufacturer      7229
# model             5412
# condition            0
# cylinders            0
# fuel              1966
# odometer             0
# title_status      1374
# transmission      1316
# vin                  0
# drive                0
# size            242074
# type                 0
# paint_color          0
# image_url            0
# description          2
# county          392466
# state                0
# lat               3344
# long              3344
# age                  0
# dtype: int64

# %% [markdown]
# ### Feature engineering

# %%
(df_clean["description"].str.contains("project", case = False)).sum()
# Out:
# 6691

# %%
(df_clean["description"].str.contains("parts", case = False)).sum()
# Out:
# 10738

# %%
(df_clean["description"].str.contains("buying", case = False)).sum()
# Out:
# 52294

# %%
df_clean.drop(columns = ['county'], inplace = True)

# %%
df_clean.isnull().sum()
# Out:
# id                   0
# url                  0
# region               0
# region_url           0
# price                0
# year                 0
# manufacturer      7229
# model             5412
# condition            0
# cylinders            0
# fuel              1966
# odometer             0
# title_status      1374
# transmission      1316
# vin                  0
# drive                0
# size            242074
# type                 0
# paint_color          0
# image_url            0
# description          2
# state                0
# lat               3344
# long              3344
# age                  0
# dtype: int64

# %%
df_clean.drop(columns = ['size'], inplace = True)

# %%
df_clean.isnull().sum()
# Out:
# id                 0
# url                0
# region             0
# region_url         0
# price              0
# year               0
# manufacturer    7229
# model           5412
# condition          0
# cylinders          0
# fuel            1966
# odometer           0
# title_status    1374
# transmission    1316
# vin                0
# drive              0
# type               0
# paint_color        0
# image_url          0
# description        2
# state              0
# lat             3344
# long            3344
# age                0
# dtype: int64

# %%
df_clean.shape
# Out:
# (392466, 24)

# %%
df_clean['model'].head(40)
# Out:
# 0                         patriot
# 1                    328i m-sport
# 2                         caravan
# 3                     colorado ls
# 7             mustang convertible
# 9       odyssey ex-l, reliable, e
# 10       tacoma sr v6 - trd off r
# 11                        compass
# 12       silverado 2500hd ext cab
# 14                        liberty
# 15                       suburban
# 16                   titan pro-4x
# 17      e-series cargo e-250 work
# 18       tacoma sr v6, 6" lift, x
# 19           outback 2.5i limited
# 20                        journey
# 22                            NaN
# 23       tacoma v6 - 4dr, 4wd dou
# 24       tundra sr5, new wheels a
# 25     fiesta se, reliable, commu
# 26                            bug
# 27                         impala
# 28        fj cruiser 4dr suv 4x4,
# 29                 grand cherokee
# 30    m3 manual transmission, exc
# 31                           cr-v
# 32                 corvette coupe
# 33       tacoma sr v6 4x4, excell
# 35                           740i
# 36                            rio
# 38                         optima
# 39                     juke nismo
# 40                           nova
# 41                sequoia limited
# 42                            mdx
# 43                          f-150
# 44                    pickup 1500
# 46                       1500 4x4
# 47                    300 touring
# 48                         malibu
# Name: model, dtype: object

# %%
plt.figure(figsize = (15,15))
sns.heatmap(df_clean.isnull(), cbar=False)

# %% [markdown]
# discuss why we kept cars with same vin being sold in diff states

# %%
df_clean.drop(columns = 'model', inplace = True)

# %%
df_clean.isnull().sum()
# Out:
# id                 0
# url                0
# region             0
# region_url         0
# price              0
# year               0
# manufacturer    7229
# condition          0
# cylinders          0
# fuel            1966
# odometer           0
# title_status    1374
# transmission    1316
# vin                0
# drive              0
# type               0
# paint_color        0
# image_url          0
# description        2
# state              0
# lat             3344
# long            3344
# age                0
# dtype: int64

# %%
df_clean.dropna(axis = 0, subset = ['manufacturer'], inplace = True)

# %%
df_clean.shape
# Out:
# (385237, 23)

# %%
df_clean.isnull().sum()
# Out:
# id                 0
# url                0
# region             0
# region_url         0
# price              0
# year               0
# manufacturer       0
# condition          0
# cylinders          0
# fuel            1961
# odometer           0
# title_status    1374
# transmission    1316
# vin                0
# drive              0
# type               0
# paint_color        0
# image_url          0
# description        2
# state              0
# lat             3242
# long            3242
# age                0
# dtype: int64

# %%
df_clean.dropna(axis = 0, inplace = True)

# %%
import pickle

# %%
import pickle

with open('df_clean.pickle', 'wb') as handle:
    pickle.dump(df_clean, handle, protocol=pickle.HIGHEST_PROTOCOL)

# with open('filename.pickle', 'rb') as handle:
#     b = pickle.load(handle)

# %%
with open('df_clean.pickle', 'rb') as handle:
    b = pickle.load(handle)

# %%
b.head()
# Out:
#            id                                                url  \
# 0  7119256118  https://mohave.craigslist.org/ctd/d/lake-havas...
# 1  7120880186  https://oregoncoast.craigslist.org/cto/d/warre...
# 2  7115048251  https://greenville.craigslist.org/cto/d/sparta...
# 3  7119250502  https://mohave.craigslist.org/cto/d/lake-havas...
# 7  7120430837  https://maine.craigslist.org/cto/d/gardiner-20...
#
#                  region                          region_url  price    year  \
# 0         mohave county       https://mohave.craigslist.org   3495  2012.0
# 1          oregon coast  https://oregoncoast.craigslist.org  13750  2014.0
# 2  greenville / upstate   https://greenville.craigslist.org   2300  2001.0
# 3         mohave county       https://mohave.craigslist.org   9000  2004.0
# 7                 maine        https://maine.craigslist.org   8500  2005.0
#
#   manufacturer  condition    cylinders fuel  odometer title_status  \
# 0         jeep   like new  4 cylinders  gas   73904.0        clean
# 1          bmw       good  8 cylinders  gas   76237.0        clean
# 2        dodge  excellent  6 cylinders  gas  199000.0        clean
# 3    chevrolet  excellent  5 cylinders  gas   54000.0        clean
# 7         ford  excellent  6 cylinders  gas   62800.0        clean
#
#   transmission  vin drive         type paint_color  \
# 0    automatic    0   4wd  convertible      silver
# 1    automatic    0   rwd        sedan        grey
# 2    automatic    0   fwd        truck      orange
# 3    automatic    1   rwd       pickup         red
# 7    automatic    1   rwd  convertible      silver
#
#                                            image_url  \
# 0  https://images.craigslist.org/00B0B_k2AXIJ21ok...
# 1  https://images.craigslist.org/00U0U_3cLk0WGOJ8...
# 2  https://images.craigslist.org/00k0k_t4WqYn5nDC...
# 3  https://images.craigslist.org/00J0J_lJEzfeVLHI...
# 7  https://images.craigslist.org/00Y0Y_48vTuTqSFD...
#
#                                          description state      lat      long  \
# 0  THIS 2012 JEEP PATRIOT IS A 4CYL. AC, STEREO, ...    az  34.4554 -114.2690
# 1  Selling my 2014 BMW 328i with the following be...    or  46.1837 -123.8240
# 2  01 DODGE CARAVAN,3.3 ENGINE,AUT TRANS,199000 M...    sc  34.9352  -81.9654
# 3  2004 Chevy Colorado LS, ONLY 54000 ORIGINAL MI...    az  34.4783 -114.2710
# 7  2005 Ford Mustang Premium Convertible First ye...    me  44.2070  -69.7858
#
#     age
# 0  10.0
# 1   8.0
# 2  21.0
# 3  18.0
# 7  17.0
